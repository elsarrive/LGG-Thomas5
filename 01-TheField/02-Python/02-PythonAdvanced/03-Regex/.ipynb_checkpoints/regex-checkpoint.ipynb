# %% [markdown]
# # Regular expressions (regex) : love or hate?

# %% [markdown]
# ![commit strip](http://www.commitstrip.com/wp-content/uploads/2014/02/Strips-Le-dernier-des-vrais-codeurs-650-finalenglsih.jpg)

# %% [markdown]
# Regular expressions are used in almost all languages. It is a very powerful tool to check if the content of a variable has the shape you expect.
#
# For example, if you retrieve a phone number, you expect the variable to be composed of numbers and spaces (or dashes) but nothing more.
#
# Regular expressions not only warn you of an unwanted character but also delete/modify all those that are not desirable.

# %% [markdown]
# **There are two ways to use regular expressions:**
# * The first consists in calling the function with the pattern as the first parameter, and the string to be analyzed as the second parameter.
# * The second way is to compile the regex, and then use the methods of the created object to analyze a string passed as an argument. This method speeds up processing when a regex is used several times.

# %%
import re

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Searches the pattern in the previous string and return a `MatchObject` if matches are found,
# otherwise returns `None`.
print(len(re.findall(pattern, string)))
# Out:
# 10

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Cuts the string according to the occurrence of the pattern.
print(re.split(pattern, string))
# Out:
# ['I', 'am', 'fine', '!', 'There', 'are', 'still', '6', 'months', 'left', ':()']

# %% [markdown]
# ### A little syntax
#
#     [xy]  A possible segment list. Example[abc] equals: a, b or c
#
#     (x|y) Indicates a multiple choice type (ps|ump) equals "ps" OR "UMP"
#
#     \d    the segment is composed only of numbers, which is equivalent to [0-9].
#
#     \D    the segment is not composed of numbers, which is equivalent to [^0-9].
#
#     \s    A space, which is equivalent to [ \t\n\r\r\f\v].
#
#     \S    No space, which is equivalent to [^ \t\n\r\f\v].
#
#     \w    Alphanumeric presence, which is equivalent to [a-zA-Z0-9_].
#
#     \W    No alphanumeric presence [^a-zA-Z0-9_].
#
#     \     Is an escape character. It _unprotects_ reserved characters by restoring their original meaning.

# %% [markdown]
# ### Let's try it.
#
# If the answer is not `None`, it means the match matches. GREY is indeed a name beginning with GR followed by a character and ending with Y.

# %%
print(re.match("GR(.)?Y", "GREY"))
# (.)? means that we expect 0 or 1 character.
# 0 or 1 because of the `?` following the character `.`, which means any character
# Out:
# <re.Match object; span=(0, 4), match='GREY'>

# %%
pattern = "GR(.)?Y"
string = "GREY"

result = re.match(pattern, string)
print(result)

# It is equal to
compiled = re.compile(pattern)
result = compiled.match(string)
print(result)
# Out:
# <re.Match object; span=(0, 4), match='GREY'>
# <re.Match object; span=(0, 4), match='GREY'>

# %%
#  So in a loop the second syntax is nicer
pattern = "GR(.)?Y"
compiled = re.compile(pattern)
l = ["GREY 'S", "GRAY", "GREYISH", "A GREY"]

for elem in l:
    result = compiled.match(elem)
    print(elem, result)
# Out:
# GREY 'S <re.Match object; span=(0, 4), match='GREY'>
# GRAY <re.Match object; span=(0, 4), match='GRAY'>
# GREYISH <re.Match object; span=(0, 4), match='GREY'>
# A GREY None

# %% [markdown]
# In the following, we search for specific expressions in a string.

# %%
print(re.findall("GR(.)?Y", "GREY"))
# so here we are looking for a unique element (.)? between GR and Y
# Out:
# ['E']

# %%
# Ditto for two characters to be found
re.findall("G(.)?(.)?Y", "GREY")
# Out:
# [('R', 'E')]

# %% [markdown]
# To keep only numbers.

# %%
# Only numbers
print(re.findall(r"([\d]+)", "Hello I live on the 7th floor of 220 street of sims"))
# "+" Means 1 or more characters
# Out:
# ['7', '220']

# %% [markdown]
# And conversely, if you only want to keep the words.

# %%
# Only words
print(re.findall(r"[\w]+", "Hello I live on the 7th floor of 220 street of sims"))
# Out:
# ['Hello', 'I', 'live', 'on', 'the', '7th', 'floor', 'of', '220', 'street', 'of', 'sims']

# %% [markdown]
# ### Stop, we recap !

# %% [markdown]
# Character | Meaning
# :-------------------------:|:-------------------------:
# **.** | Refers to any character.
# **^** | Indicates the beginning of the string.<br />For example, _^a_ matches _ab_ but not _ba_.
# **$** | Indicates the end of the string.<br />For example, _a$_ matches _ba_ but not _ab_.
# **?**| The previous character can be repeated zero or once.<br /> For example, _ab?_ corresponds to _ab_ and _a_.
#  *| The previous character can be repeated none or several times. <br />For example, _ab\*_ may correspond to: _a_, _ab_, or _a_ followed by any number of _b_.
# **+**| The previous character can be repeated once or several times. <br/>For example, to _ab+_ corresponds an _a_ followed by any number of _b_.
# **{n}**| Indicates that the previous character must be repeated _n_ times.
# **{n, m}**|Indicates that the previous character must be repeated between _n_ and _m_ times.
# **\w** | It corresponds to any alphabetical character, it is equivalent to _[a-zA-Z]_.
# **\W** | It corresponds to everything that is not an alphabetical character.
# **\d** | It corresponds to any numeric character, i.e. it is equivalent to _[0-9]_.
# **\D** | It corresponds to everything that is not a numeric character.

# %% [markdown]
# <img src="https://i.redd.it/nac35ntlfg831.jpg" width="400">

# %% [markdown]
# ### Some useful resources
# [Regex quickstart](http://www.rexegg.com/regex-quickstart.html): the Regex cheat sheet
#
# [Dreambank Regex](http://www.dreambank.net/regex.html#examples): some examples of regex behaviour
#
# [Pythex](https://pythex.org/): a real-time regular expression editor for Python, a quick way to test your regular expressions.
#
# [Regex101](https://regex101.com/): online regex editor and debugger. Regex101 allows you to create, debug, test and have your expressions explained for PHP, PCRE, Python, Golang and JavaScript. The website also features a community where you can share useful expressions.
#
# ##### And just for fun...
# [Regex Crosswords](https://regexcrossword.com/): some crossword puzzles to test your Regex knowledge

# %% [markdown]
# #### How to check that the entered string is that of a number ?

# %%
number = input("Your number : ")
if re.match("^[0-9]+$", number):
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number.")
# Out:
# Your number :  543
# The string entered is a number.

# %% [markdown]
# Another way

# %%
compiled = re.compile("^[0-9]+$")
if compiled.search(number) is not None:
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number")
# Out:
# The string entered is a number.

# %% [markdown]
# ### Drill

# %% [markdown]
# **1. Create a regex that finds integers without size limit.**

# %%
s = "sssgdds86sfsf6s"
compiled = re.compile(r"\d+")
result = compiled.findall(s)
if result is not None:
    print(result)
# Out:
# ['86', '6']

# %% [markdown]
# **2. Create a regex that finds negative integers without size limit.**

# %%
s = "sssgdds-8sfs4f-87s"
compiled = re.compile(r"-\d+")
result = compiled.findall(s)
if result is not None:
    print(result)
# Out:
# ['-8', '-87']

# %% [markdown]
# **3. Create a regex that finds (positive or negative) integers without size limit.**

# %%
s = "sssg-6dds-8s8fsf87s"
compiled = re.compile(r"-?\d+")
result = compiled.findall(s)
if result is not None:
    print(result)
# Out:
# ['-6', '-8', '8', '87']

# %% [markdown]
# **4. Capture all the numbers of the following sentence :**

# %%
text = "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy."
searchfor = re.compile(r"[+-]?\d{1,3}(?:,\d{3})*(?:\.\d+)?")
result = searchfor.findall(text)
if result is not None:
    print(result)
# Out:
# ['21', '3', '4,003', '100.00']

# %% [markdown]
# **5. Find all words that end with 'ly'.**

# %%
text = "He had prudently disguised himself but was quickly captured by the police."
pattern = re.compile(r"\b\w+ly\b")
result = re.findall(pattern, text)
print(result)
# Out:
# ['prudently', 'quickly']

# %% [markdown]
# **6. License plate number**
# A Belgian license plate consists of 1 digit (0, 1 or 2), a dash ('-'), 3 capital letters, a dash ('-') and finally 3 digits. Write a script to check that an input string is a valid license plate.
# If it's correct, print `"good"`. If it's not correct, print `"Not good"`.

# %%
plate = input("Enter your license plate number: ")
pattern = re.compile(r"\d+-[A-Z]{3}-\d{3}")
if pattern.search(plate) is not None: 
    print("Good")
else: 
    print("Not good")
# Out:
# Enter your license plate number:  1-AAA-PPP
# Not good

# %% [markdown]
# **7. Address IPV4**
# An IPv4 address is composed of 4 numbers between 0 and 255 separated by '.'
# Write a script to verify that a string entered is a valid IPv4 address.

# %%
ip = input("Enter your IP address :")
pattern = re.compile(r"\b(25[0-5]|2[0-4][0-9]|1?[0-9][0-9]?)\."
                     r"(25[0-5]|2[0-4][0-9]|1?[0-9][0-9]?)\."
                     r"(25[0-5]|2[0-4][0-9]|1?[0-9][0-9]?)\."
                     r"(25[0-5]|2[0-4][0-9]|1?[0-9][0-9]?)\b")
if pattern.search(ip) is not None: 
    print ("Valid IP address")
else:
    print("Invalid IP address")
# Out:
# Enter your IP address : 111.111.111.111
# Valid IP address

# %% [markdown]
# **8. Valid Mail**
# An email is composed of alphanumeric characters followed by `@` and a domain name.
# Write a script that checks that the string entered by a user is indeed that of an email, otherwise ask him to re-enter it again (until he gets a valid email).

# %%
mail = input("Enter your email :")
pattern = re.compile(r"^[a-zA-Z0-9._-]+@[a-z.-]+\.[a-z]{2,3}$")
if pattern.search(mail) is not None: 
    print("Valid e-mail")
else:
    print("Invalid e-mail")
# Out:
# Enter your email : elsa@gm.com
# Valid e-mail

# %% [markdown]
# **9. Valid Password**
# Write an additional script that verifies the password (obviously if the email is valid) where the only specificity of the password is that it has to contain at least 6 characters.

# %%
password = input("Enter your password :")
if pattern.search(mail) is not None and len(password) >= 6:
    print('ok')
else:
    print('ko')
# Out:
# Enter your password : ytrezsdc
# ko

# %% [markdown]
# **10. Valid Password bis**
# The password must now contain at least 6 characters AND
#
# - at least one lowercase letter AND
# - at least one uppercase letter AND
# - at least one number AND
# - at least one special character (among `$#@`).

# %%
mail = input("Enter your email :")
mail_pattern = re.compile(r"^[a-zA-Z0-9._-]+@[a-z.-]+\.[a-z]{2,3}$")
if mail_pattern.search(mail) is not None: 
    print("-> Valid e-mail")
else:
    print("-> Invalid e-mail")
    


if mail_pattern.search(mail):
    password = input("Enter your password :")
    password_pattern = re.compile(r"^(?=.*[a-z])(?=.*[A-Z])(?=.*[$@#]).{8,}$")
    if password_pattern.search(password) is not None:
        print('-> ok')
    else:
        print('-> ko')
# Out:
# Enter your email : e@g.maaaa
# -> Invalid e-mail

# %% [markdown]
# **11. Search by groups**
# It is possible to search by groups, and it is very powerful!
# `?P<x>\w+` means the capture of a "group" named `x`, this group is composed of at least (`+`) one alphanumeric  character `(\w)`.

# %%
m = re.search(
    r"Welcome to (?P<where>\w+) ! You are (?P<age>\d+) years old ?",
    "Welcome to Olivier ! You are 32 years old ?",
)
print(m.group("where"))
print(m.group("age"))
# Out:
# Olivier
# 32

# %%
# Another Example
m = re.search(
    r"^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w*)[.](?P<zone>\w*$)",
    "audrey.boulevart@benextcomapgny.com",
)
if m is not None:
    print(m.group("who"))
    print(m.group("who2"))
    print(m.group("operator"))
    print(m.group("zone"))
# Out:
# audrey
# boulevart
# benextcomapgny
# com

# %% [markdown]
# Load the file `./data/mail.txt` and clean it with the regex. The goal is to retrieve the last name, first name, operator and zone, as in the previous example. Store each of those into their own separate list.

# %%
with open("./data/mail.txt") as file: 
    list_mail = file.readlines()
    #print(list_mail)
    
pattern = r"^(?P<name>\w+)[._-](?P<last_name>\w+)@(?P<operator>\w+)[.](?P<zone>\w{2,6})$"
pattern2 = r"^(?P<name>\w+)@(?P<operator>\w+)\.(?P<zone>\w{2,6})$"

for email in list_mail:
    research_email = re.search(pattern, email)
    research_email2 = re.search(pattern2, email)
    
    if research_email: 
        print(f"Match found in {email} Name : {research_email.group("name").capitalize()}, surname : {research_email.group("last_name").capitalize()}")

    else: 
        print(f"No match found in {email}")
# Out:
# No match found in vogal-roger@mail.adlp.tech
#
# Match found in aikin.joe@odul.xyz
#  Name : Aikin, surname : Joe
# No match found in moore@imail.gov
#
# No match found in halknutson@email.xyz
#
# No match found in alexnorquist@proton.com
#
# No match found in matthewlulloff@mail.adlp.me
#
# Match found in jenson-thomas@belgaximus.org
#  Name : Jenson, surname : Thomas
# No match found in mark4451@mail.bocode.gov
#
# Match found in monte.hylan@belgaximus.net
#  Name : Monte, surname : Hylan
# No match found in dan80@mail.adlp.com
#
# Match found in schmitt-steve@napster.org
#  Name : Schmitt, surname : Steve
# No match found in knutsondan@belgaximus.org
#
# No match found in lepage@gaagle.xyz
#
# Match found in chapman_ben@napster.hu
#  Name : Chapman, surname : Ben
# No match found in upson1544@youhoo.hu
#
# No match found in 552966959@belgaximus.hu
#
# Match found in soloman_ziegler@email.tech
#  Name : Soloman, surname : Ziegler
# Match found in ortiz.mark@napster.me
#  Name : Ortiz, surname : Mark
# Match found in ashwoon_hank@imail.io
#  Name : Ashwoon, surname : Hank
# No match found in pettigrew@proton.hu
#
# No match found in doranedward@napster.net
#
# Match found in mills_joe@imail.xyz
#  Name : Mills, surname : Joe
# No match found in valente_alex@mail.adlp.net
#
# No match found in yang@email.hu
#
# No match found in ike@ecoin.io
#
# No match found in hankshaffer@mail.bocode.io
#
# No match found in larrytrebil@email.org
#
# Match found in davis_ike@odul.io
#  Name : Davis, surname : Ike
# No match found in davidsonhal@hotmoille.apple
#
# No match found in john8733@youhoo.com
#
# No match found in johnfletcher@youhoo.me
#
# Match found in cataldi_larry@napster.com
#  Name : Cataldi, surname : Larry
# No match found in rogerfietzer@imail.apple
#
# No match found in edward4185@gaagle.gov
#
# Match found in hancock_matthew@belgaximus.gov
#  Name : Hancock, surname : Matthew
# Match found in solberg_cast@gaagle.apple
#  Name : Solberg, surname : Cast
# Match found in vader-jack@youhoo.hu
#  Name : Vader, surname : Jack
# No match found in georgepak@gaagle.me
#
# Match found in caswell-hal@ecoin.io
#  Name : Caswell, surname : Hal
# No match found in ike@ecoin.com
#
# Match found in tapia_quinn@gaagle.io
#  Name : Tapia, surname : Quinn
# No match found in 795419860@imail.tech
#
# No match found in chambers_johnsen@mail.bocode.me
#
# No match found in jack@gaagle.apple
#
# No match found in joe@ecoin.tech
#
# No match found in reyesaaron@mail.adlp.hu
#
# Match found in ben.yang@ecoin.com
#  Name : Ben, surname : Yang
# No match found in pettigrewgeorge@odul.me
#
# No match found in miller.peter@mail.bocode.xyz
#
# Match found in linde-carl@belgaximus.org
#  Name : Linde, surname : Carl
# Match found in boyd_carl@napster.me
#  Name : Boyd, surname : Carl
# Match found in yocum_mark@youhoo.com
#  Name : Yocum, surname : Mark
# No match found in davidferro@mail.bocode.com
#
# No match found in george59@ecoin.gov
#
# No match found in johnsen2201@imail.io
#
# No match found in thompson_adam@mail.bocode.me
#
# No match found in schutzlarry@email.apple
#
# Match found in quizoz.joe@napster.tech
#  Name : Quizoz, surname : Joe
# No match found in matthew8227@hotmoille.me
#
# No match found in alex@mail.bocode.net
#
# No match found in georgemoody@hotmoille.com
#
# No match found in lawicki589@hotmoille.me
#
# No match found in doran7947@gaagle.tech
#
# No match found in baueraaron@mail.adlp.gov
#
# No match found in mark@email.io
#
# No match found in waltermartin@ecoin.gov
#
# No match found in kaskel@mail.bocode.tech
#
# No match found in roberts_matthew@mail.bocode.hu
#
# No match found in george@hotmoille.hu
#
# Match found in ferry.victor@gaagle.com
#  Name : Ferry, surname : Victor
# Match found in fred.weiss@odul.tech
#  Name : Fred, surname : Weiss
# No match found in jurgensonpeter@proton.tech
#
# No match found in stevefietzer@ecoin.tech
#
# Match found in sonderling_caswell@napster.tech
#  Name : Sonderling, surname : Caswell
# Match found in johnsen.walter@odul.net
#  Name : Johnsen, surname : Walter
# No match found in mccormack@napster.xyz
#
# Match found in roberts.hank@proton.net
#  Name : Roberts, surname : Hank
# No match found in valente@gaagle.xyz
#
# Match found in ory_walter@proton.hu
#  Name : Ory, surname : Walter
# No match found in tyirwin@proton.tech
#
# No match found in paulferry@hotmoille.com
#
# No match found in george@youhoo.gov
#
# No match found in frank.lulloff@mail.adlp.apple
#
# No match found in ripka6596@mail.bocode.net
#
# No match found in wagner_schuster@mail.adlp.me
#
# Match found in mccormack.carl@imail.xyz
#  Name : Mccormack, surname : Carl
# No match found in 851886792@youhoo.hu
#
# Match found in zeaser_aaron@belgaximus.apple
#  Name : Zeaser, surname : Aaron
# No match found in adam@proton.net
#
# Match found in tisler.roger@hotmoille.tech
#  Name : Tisler, surname : Roger
# Match found in ferro-dan@proton.io
#  Name : Ferro, surname : Dan
# Match found in reardon-alex@gaagle.tech
#  Name : Reardon, surname : Alex
# Match found in severson_george@proton.org
#  Name : Severson, surname : George
# Match found in otto.nuttle@proton.hu
#  Name : Otto, surname : Nuttle
# No match found in illingsworth@belgaximus.gov
#
# No match found in danfletcher@mail.adlp.net
#
# No match found in alex685@hotmoille.com
#
# Match found in hancock_valente@hotmoille.net
#  Name : Hancock, surname : Valente
# No match found in carl7884@mail.adlp.apple
#
# No match found in paul9581@email.tech
#
# Match found in sawyer_chambers@belgaximus.xyz
#  Name : Sawyer, surname : Chambers
# Match found in johnsen.tim@email.gov
#  Name : Johnsen, surname : Tim
# Match found in aaron.roberts@imail.gov
#  Name : Aaron, surname : Roberts
# No match found in schiebel2392@hotmoille.xyz
#
# No match found in mccormackedward@proton.com
#
# No match found in tapia1876@imail.tech
#
# No match found in quizoz9628@belgaximus.apple
#
# No match found in rogerstahl@odul.apple
#
# Match found in schutz_johnsen@ecoin.tech
#  Name : Schutz, surname : Johnsen
# Match found in schutz-monte@hotmoille.net
#  Name : Schutz, surname : Monte
# No match found in carlupson@napster.me
#
# No match found in larry349@odul.me
#
# Match found in matthew.linde@youhoo.tech
#  Name : Matthew, surname : Linde
# No match found in mcginnis@imail.xyz
#
# No match found in kalleg.monte@mail.adlp.com
#
# Match found in nugent_jack@gaagle.hu
#  Name : Nugent, surname : Jack
# Match found in wagle_john@napster.gov
#  Name : Wagle, surname : John
# No match found in chapmannathan@youhoo.org
#
# Match found in christensen-larry@hotmoille.net
#  Name : Christensen, surname : Larry
# No match found in hal536@napster.net
#
# No match found in 472510707@odul.io
#
# Match found in thomas.casal@hotmoille.com
#  Name : Thomas, surname : Casal
# No match found in adamillingsworth@youhoo.xyz
#
# No match found in weiss-adam@mail.adlp.tech
#
# No match found in peterstahl@gaagle.me
#
# No match found in victortandy@youhoo.hu
#
# No match found in fredturco@mail.bocode.hu
#
# Match found in adam.sellon@email.tech
#  Name : Adam, surname : Sellon
# Match found in vader-matthew@belgaximus.gov
#  Name : Vader, surname : Matthew
# No match found in ike3831@proton.apple
#
# No match found in timfletcher@imail.xyz
#
# Match found in frank.schickowski@gaagle.io
#  Name : Frank, surname : Schickowski
# No match found in 566486749@email.net
#
# No match found in 675340599@proton.org
#
# Match found in davis_nathan@ecoin.com
#  Name : Davis, surname : Nathan
# No match found in 253159777@gaagle.net
#
# No match found in edwardschutz@hotmoille.net
#
# Match found in sagar_carl@hotmoille.org
#  Name : Sagar, surname : Carl
# No match found in 331837931@napster.me
#
# No match found in aaronbongard@odul.xyz
#
# No match found in ty9516@belgaximus.net
#
# No match found in fred@mail.adlp.apple
#
# No match found in schustersteve@proton.tech
#
# Match found in moody_schiebel@hotmoille.me
#  Name : Moody, surname : Schiebel
# Match found in soloman_ramachandran@gaagle.org
#  Name : Soloman, surname : Ramachandran
# No match found in victor630@hotmoille.hu
#
# Match found in yang_trebil@imail.me
#  Name : Yang, surname : Trebil
# Match found in hoffman_zeller@imail.me
#  Name : Hoffman, surname : Zeller
# Match found in ripka_thomas@email.tech
#  Name : Ripka, surname : Thomas
# Match found in vader.hal@belgaximus.org
#  Name : Vader, surname : Hal
# No match found in ottochambers@imail.io
#
# No match found in tylulloff@email.gov
#
# No match found in 263935905@youhoo.tech
#
# No match found in carlvail@napster.me
#
# No match found in hanktisler@ecoin.com
#
# No match found in uddin1510@email.org
#
# Match found in mccormack.carl@proton.net
#  Name : Mccormack, surname : Carl
# No match found in vader@proton.me
#
# No match found in nelsonmark@imail.xyz
#
# No match found in adamvan zandt@belgaximus.hu
#
# Match found in ziegler-dan@proton.me
#  Name : Ziegler, surname : Dan
# No match found in uflan@mail.adlp.gov
#
# Match found in sawyer-frank@ecoin.net
#  Name : Sawyer, surname : Frank
# No match found in dan6858@mail.adlp.io
#
# No match found in stahl@odul.apple
#
# No match found in timirwin@hotmoille.me
#
# No match found in davis9134@imail.tech
#
# No match found in benuflan@mail.adlp.org
#
# No match found in davidziegler@imail.tech
#
# No match found in carl1959@youhoo.apple
#
# No match found in alexkeller@gaagle.com
#
# No match found in ostranderjoe@mail.bocode.tech
#
# No match found in 469322116@hotmoille.tech
#
# No match found in monte7207@gaagle.hu
#
# No match found in lawicki@mail.adlp.io
#
# No match found in fredtiernan@email.net
#
# No match found in fietzer@gaagle.org
#
# No match found in benquinn@proton.com
#
# No match found in matthew8594@mail.adlp.xyz
#
# Match found in hal.weiss@email.xyz
#  Name : Hal, surname : Weiss
# Match found in sweeney.otto@gaagle.apple
#  Name : Sweeney, surname : Otto
# Match found in fletcher_monte@email.com
#  Name : Fletcher, surname : Monte
# No match found in adamkalleg@mail.bocode.hu
#
# No match found in woothomas@napster.tech
#
# No match found in thomasdavidson@mail.bocode.io
#
# No match found in moore3490@mail.adlp.me
#
# No match found in walter@napster.io
#
# No match found in ventotla.alex@mail.adlp.tech
#
# No match found in dinkins@proton.gov
#
# No match found in 950099319@imail.net
#
# Match found in roger.myers@gaagle.io
#  Name : Roger, surname : Myers
# Match found in tim.trusela@hotmoille.gov
#  Name : Tim, surname : Trusela
# Match found in sawyer.adam@belgaximus.org
#  Name : Sawyer, surname : Adam
# Match found in ben.jagtap@napster.tech
#  Name : Ben, surname : Jagtap
# No match found in carlmills@ecoin.me
#
# No match found in markboyd@belgaximus.apple
#
# No match found in johnyocum@mail.adlp.apple
#
# No match found in 887934540@email.net
#
# No match found in ortizjack@gaagle.gov
#
# No match found in tiernan4456@mail.adlp.xyz
#
# Match found in roberts_myers@email.tech
#  Name : Roberts, surname : Myers
# No match found in soloman8370@odul.gov
#
# No match found in alex3716@ecoin.me
#
# No match found in tim@proton.me
#
# No match found in thompson85@proton.hu
#
# Match found in reyes.jack@email.hu
#  Name : Reyes, surname : Jack
# No match found in resnick@mail.bocode.hu
#
# No match found in dinkinsroger@youhoo.apple
#
# No match found in mills9634@odul.xyz
#
# No match found in 821464747@odul.gov
#
# Match found in valente_hydinger@hotmoille.tech
#  Name : Valente, surname : Hydinger
# No match found in schiebel1467@proton.io
#
# No match found in larryschiebel@ecoin.net
#
# No match found in adamostrander@mail.adlp.gov
#
# Match found in jagtap.fred@proton.gov
#  Name : Jagtap, surname : Fred
# Match found in edward.haworth@imail.com
#  Name : Edward, surname : Haworth
# No match found in matthewcataldi@youhoo.net
#
# No match found in resnick_moore@mail.adlp.tech
#
# No match found in zeller@email.org
#
# Match found in trebil-george@youhoo.apple
#  Name : Trebil, surname : George
# No match found in duffman@email.net
#
# No match found in ottoortiz@youhoo.xyz
#
# No match found in david.rice@mail.bocode.org
#
# No match found in delorenzo@ecoin.me
#
# Match found in miller_keller@email.org
#  Name : Miller, surname : Keller
# No match found in illingsworth@youhoo.gov
#
# No match found in nelson@odul.tech
#
# Match found in rogers_john@gaagle.tech
#  Name : Rogers, surname : John
# No match found in fredwagner@mail.adlp.org
#
# No match found in tyresnick@imail.io
#
# Match found in hal.yang@napster.xyz
#  Name : Hal, surname : Yang
# No match found in tiernan6950@belgaximus.tech
#
# Match found in schuster-john@email.tech
#  Name : Schuster, surname : John
# No match found in mills@belgaximus.xyz
#
# Match found in casal.hank@proton.xyz
#  Name : Casal, surname : Hank
# No match found in roger.van zandt@gaagle.org
#
# No match found in stevevader@mail.bocode.me
#
# No match found in hankupson@odul.xyz
#
# No match found in 184536366@mail.adlp.me
#
# Match found in irwin_yang@gaagle.gov
#  Name : Irwin, surname : Yang
# Match found in napier.aaron@email.org
#  Name : Napier, surname : Aaron
# Match found in edward.schickowski@youhoo.xyz
#  Name : Edward, surname : Schickowski
# Match found in fletcher-alex@imail.com
#  Name : Fletcher, surname : Alex
# No match found in chambers-monte@mail.adlp.gov
#
# Match found in rogers_lawicki@gaagle.apple
#  Name : Rogers, surname : Lawicki
# Match found in tapia_upson@ecoin.me
#  Name : Tapia, surname : Upson
# Match found in uddin_yocum@gaagle.hu
#  Name : Uddin, surname : Yocum
# No match found in bongardroger@napster.net
#
# No match found in victor@youhoo.gov
#
# Match found in ty.schwager@napster.io
#  Name : Ty, surname : Schwager
# No match found in paultiernan@youhoo.xyz
#
# No match found in roger836@gaagle.tech
#
# Match found in pettigrew.victor@email.io
#  Name : Pettigrew, surname : Victor
# No match found in steve.ingram@mail.bocode.me
#
# No match found in johnsen4863@gaagle.apple
#
# Match found in soloman-roger@ecoin.apple
#  Name : Soloman, surname : Roger
# No match found in 34658710@mail.bocode.xyz
#
# No match found in cannon-joe@mail.bocode.io
#
# No match found in 284857146@mail.adlp.net
#
# No match found in 890280316@ecoin.me
#
# Match found in kalleg-joe@belgaximus.com
#  Name : Kalleg, surname : Joe
# Match found in weinstein.roger@imail.io
#  Name : Weinstein, surname : Roger
# No match found in alexschmitt@odul.org
#
# Match found in dan.uddin@ecoin.apple
#  Name : Dan, surname : Uddin
# Match found in steve.stahl@hotmoille.me
#  Name : Steve, surname : Stahl
# No match found in matthewfrick@hotmoille.com
#
# No match found in 237336989@email.io
#
# No match found in larry6016@youhoo.org
#
# No match found in otto5489@gaagle.tech
#
# Match found in bongard_ty@ecoin.xyz
#  Name : Bongard, surname : Ty
# No match found in 169102677@gaagle.me
#
# Match found in upson.hal@gaagle.io
#  Name : Upson, surname : Hal
# No match found in hal@hotmoille.gov
#
# Match found in lepage-aaron@hotmoille.apple
#  Name : Lepage, surname : Aaron
# Match found in sonderling_mark@belgaximus.me
#  Name : Sonderling, surname : Mark
# No match found in 430581778@hotmoille.com
#
# No match found in walterkassing@napster.tech
#
# No match found in victorceledon@ecoin.xyz
#
# Match found in hesch-john@odul.io
#  Name : Hesch, surname : John
# No match found in kassing@hotmoille.apple
#
# No match found in duffman6005@youhoo.hu
#
# Match found in frank.ventotla@belgaximus.io
#  Name : Frank, surname : Ventotla
# No match found in uddinotto@youhoo.org
#
# No match found in 703979481@ecoin.apple
#
# Match found in paul.nugent@ecoin.apple
#  Name : Paul, surname : Nugent
# No match found in nugent@proton.org
#
# No match found in alex@odul.tech
#
# No match found in aaronsweeney@ecoin.apple
#
# Match found in knutson_celedon@hotmoille.xyz
#  Name : Knutson, surname : Celedon
# No match found in tydoran@belgaximus.org
#
# No match found in millerhal@hotmoille.org
#
# No match found in adamnuttle@youhoo.hu
#
# No match found in ashwoon8609@youhoo.tech
#
# No match found in victormiller@mail.bocode.org
#
# Match found in mcginnis_reardon@youhoo.org
#  Name : Mcginnis, surname : Reardon
# Match found in ramachandran.mark@proton.com
#  Name : Ramachandran, surname : Mark
# No match found in monteshaffer@proton.tech
#
# No match found in monte@proton.gov
#
# No match found in pettigrew9750@proton.com
#
# Match found in yocum_dan@napster.xyz
#  Name : Yocum, surname : Dan
# Match found in yocum-victor@imail.xyz
#  Name : Yocum, surname : Victor
# No match found in darnell8483@email.xyz
#
# Match found in zeller-matthew@ecoin.apple
#  Name : Zeller, surname : Matthew
# No match found in pettigrewlarry@imail.tech
#
# No match found in yocum8146@mail.bocode.me
#
# No match found in ben5039@hotmoille.tech
#
# Match found in mcginnis.dan@gaagle.tech
#  Name : Mcginnis, surname : Dan
# Match found in roger.vogal@email.xyz
#  Name : Roger, surname : Vogal
# No match found in adamtisler@gaagle.xyz
#
# No match found in matthew3420@hotmoille.tech
#
# No match found in john8770@napster.hu
#
# Match found in hesch_zeller@email.apple
#  Name : Hesch, surname : Zeller
# Match found in christensen_ben@proton.com
#  Name : Christensen, surname : Ben
# Match found in walter.soulis@email.com
#  Name : Walter, surname : Soulis
# No match found in ben8671@proton.tech
#
# No match found in frankjagtap@napster.com
#
# No match found in peternuttle@napster.gov
#
# No match found in victor8847@ecoin.io
#
# Match found in ferry.paul@imail.org
#  Name : Ferry, surname : Paul
# No match found in 690377034@gaagle.apple
#
# No match found in lepageroger@proton.gov
#
# Match found in john.zeaser@imail.gov
#  Name : John, surname : Zeaser
# Match found in valente-jack@gaagle.me
#  Name : Valente, surname : Jack
# No match found in 4709006@napster.tech
#
# Match found in deitz-monte@odul.gov
#  Name : Deitz, surname : Monte
# Match found in fietzer-frank@hotmoille.tech
#  Name : Fietzer, surname : Frank
# No match found in kaskel5284@belgaximus.org
#
# No match found in davidson-monte@mail.bocode.xyz
#
# No match found in cataldi_ingram@mail.bocode.tech
#
# No match found in hanktiernan@youhoo.io
#
# No match found in ripka2474@hotmoille.tech
#
# Match found in cataldi_matthew@odul.me
#  Name : Cataldi, surname : Matthew
# No match found in lewis_lulloff@mail.adlp.org
#
# No match found in matthewmccord@mail.bocode.me
#
# No match found in turco8476@mail.adlp.apple
#
# No match found in steve6967@odul.hu
#
# Match found in ortiz-larry@napster.org
#  Name : Ortiz, surname : Larry
# No match found in irwincarl@belgaximus.gov
#
# No match found in wakefieldjoe@ecoin.org
#
# No match found in nathansagar@email.apple
#
# Match found in hydinger_larry@odul.xyz
#  Name : Hydinger, surname : Larry
# Match found in frank.yates@proton.gov
#  Name : Frank, surname : Yates
# No match found in fred@mail.adlp.apple
#
# No match found in schuster5868@youhoo.tech
#
# No match found in rogerschwager@imail.tech
#
# No match found in 163622426@imail.com
#
# No match found in baxstercarl@proton.net
#
# No match found in yang-hal@mail.adlp.net
#
# No match found in aikin@napster.gov
#
# No match found in ortiz-david@mail.adlp.io
#
# Match found in tisler_reyes@imail.io
#  Name : Tisler, surname : Reyes
# No match found in stahl-thomas@mail.bocode.org
#
# No match found in aaron.trusela@mail.adlp.gov
#
# No match found in 573168868@mail.adlp.tech
#
# No match found in monte1021@hotmoille.gov
#
# No match found in petermccord@mail.bocode.xyz
#
# No match found in quizoz@proton.apple
#
# Match found in vail_soukup@proton.apple
#  Name : Vail, surname : Soukup
# No match found in thomassonderling@napster.com
#
# No match found in frankaikin@odul.io
#
# No match found in aaronillingsworth@hotmoille.com
#
# No match found in 859491337@youhoo.hu
#
# Match found in paul.eastman@napster.io
#  Name : Paul, surname : Eastman
# No match found in waltertisler@belgaximus.apple
#
# Match found in ferro_caswell@hotmoille.com
#  Name : Ferro, surname : Caswell
# No match found in george@gaagle.hu
#
# No match found in timorwig@email.io
#
# No match found in jones@napster.net
#
# Match found in hoffman.roger@youhoo.xyz
#  Name : Hoffman, surname : Roger
# No match found in ashwoon@mail.bocode.tech
#
# Match found in matthew.trusela@imail.io
#  Name : Matthew, surname : Trusela
# No match found in larry2207@imail.apple
#
# Match found in rice_sonderling@gaagle.hu
#  Name : Rice, surname : Sonderling
# No match found in nuttleben@proton.net
#
# Match found in dewalt_martin@belgaximus.io
#  Name : Dewalt, surname : Martin
# No match found in ikekassing@gaagle.com
#
# No match found in 240044289@odul.tech
#
# No match found in otto@napster.hu
#
# Match found in ferro.edward@imail.xyz
#  Name : Ferro, surname : Edward
# No match found in hankanderson@imail.net
#
# Match found in deitz-roger@odul.net
#  Name : Deitz, surname : Roger
# No match found in turco_ike@mail.adlp.xyz
#
# Match found in dan.deitz@belgaximus.gov
#  Name : Dan, surname : Deitz
# Match found in orwig_sweeney@proton.me
#  Name : Orwig, surname : Sweeney
# No match found in bencaswell@youhoo.apple
#
# Match found in chambers.victor@email.net
#  Name : Chambers, surname : Victor
# No match found in sweeney_david@mail.bocode.hu
#
# No match found in 579081959@ecoin.hu
#
# Match found in moore.fred@imail.com
#  Name : Moore, surname : Fred
# No match found in thomas@gaagle.me
#
# Match found in darnell-otto@imail.com
#  Name : Darnell, surname : Otto
# No match found in orwig@imail.tech
#
# Match found in haworth-john@imail.org
#  Name : Haworth, surname : John
# No match found in nathankalleg@mail.bocode.xyz
#
# No match found in hal@imail.me
#
# No match found in yocum@mail.bocode.me
#
# No match found in robertsalex@mail.adlp.gov
#
# No match found in alex9835@email.org
#
# Match found in roberts-hank@hotmoille.hu
#  Name : Roberts, surname : Hank
# No match found in nathanripka@belgaximus.com
#
# No match found in sonderling@napster.xyz
#
# Match found in matthew.duffman@gaagle.net
#  Name : Matthew, surname : Duffman
# No match found in monte2098@odul.io
#
# Match found in victor.tiernan@email.hu
#  Name : Victor, surname : Tiernan
# No match found in cataldi_john@mail.bocode.org
#
# No match found in 822140569@proton.net
#
# No match found in joe@hotmoille.com
#
# No match found in matthew@gaagle.tech
#
# No match found in walter@napster.net
#
# No match found in baxster_zeaser@mail.bocode.hu
#
# Match found in schickowski-hal@proton.apple
#  Name : Schickowski, surname : Hal
# Match found in moody-alex@odul.org
#  Name : Moody, surname : Alex
# Match found in yocum_ventotla@email.tech
#  Name : Yocum, surname : Ventotla
# Match found in vader_sweeney@ecoin.hu
#  Name : Vader, surname : Sweeney
# No match found in schutz@mail.adlp.hu
#
# Match found in orwig_mills@youhoo.me
#  Name : Orwig, surname : Mills
# No match found in roger7781@odul.io
#
# Match found in dugan_thomas@odul.tech
#  Name : Dugan, surname : Thomas
# No match found in lulloff@mail.adlp.net
#
# No match found in vader@gaagle.apple
#
# No match found in otto@gaagle.xyz
#
# Match found in sawyer_johnson@hotmoille.apple
#  Name : Sawyer, surname : Johnson
# No match found in george@hotmoille.net
#
# Match found in anderson.john@hotmoille.gov
#  Name : Anderson, surname : John
# Match found in hydinger_aaron@ecoin.com
#  Name : Hydinger, surname : Aaron
# No match found in monte@hotmoille.com
#
# Match found in severson_aaron@proton.io
#  Name : Severson, surname : Aaron
# Match found in jack.fletcher@napster.com
#  Name : Jack, surname : Fletcher
# No match found in jurgensonpaul@ecoin.io
#
# No match found in 438861443@ecoin.gov
#
# No match found in aaron@proton.com
#
# No match found in fletcher_thompson@mail.adlp.com
#
# No match found in weiss2334@mail.bocode.net
#
# Match found in eastman-ty@belgaximus.me
#  Name : Eastman, surname : Ty
# No match found in doran@email.org
#
# Match found in sweeney_nathan@proton.xyz
#  Name : Sweeney, surname : Nathan
# No match found in vogal9413@mail.bocode.tech
#
# Match found in celedon_bauer@gaagle.net
#  Name : Celedon, surname : Bauer
# No match found in vader-victor@mail.adlp.tech
#
# No match found in 873166067@mail.bocode.net
#
# Match found in ben.bongard@hotmoille.com
#  Name : Ben, surname : Bongard
# No match found in carl.weiss@mail.bocode.me
#
# No match found in 421931320@belgaximus.gov
#
# Match found in cataldi_haworth@gaagle.com
#  Name : Cataldi, surname : Haworth
# No match found in vogal-carl@mail.bocode.xyz
#
# No match found in 290273746@hotmoille.me
#
# No match found in tybauer@imail.apple
#
# No match found in larrymyers@hotmoille.tech
#
# Match found in soloman-jack@imail.gov
#  Name : Soloman, surname : Jack
# No match found in rice_mark@mail.bocode.me
#
# No match found in orymonte@youhoo.me
#
# No match found in mcginnis-tim@mail.adlp.xyz
#
# No match found in nathanhancock@mail.adlp.net
#
# Match found in lawless.fred@imail.tech
#  Name : Lawless, surname : Fred
# No match found in paulkassing@mail.adlp.gov
#
# No match found in fredroot@odul.com
#
# Match found in hesch-ty@napster.tech
#  Name : Hesch, surname : Ty
# No match found in napier3011@email.com
#
# No match found in napier_ortiz@mail.bocode.org
#
# No match found in tynapier@napster.org
#
# No match found in ty3947@ecoin.io
#
# No match found in ben@odul.com
#
# No match found in resnickmonte@mail.bocode.hu
#
# No match found in sawyer@imail.com
#
# Match found in kaskel-peter@youhoo.tech
#  Name : Kaskel, surname : Peter
# No match found in schwager9365@hotmoille.io
#
# No match found in aaronlewis@proton.gov
#
# Match found in nelson_jack@gaagle.apple
#  Name : Nelson, surname : Jack
# No match found in upson1390@proton.apple
#
# No match found in 871781143@odul.org
#
# No match found in 269062053@youhoo.me
#
# No match found in victorreardon@proton.com
#
# No match found in soloman@gaagle.tech
#
# No match found in aaronsagar@ecoin.org
#
# No match found in alex@odul.hu
#
# No match found in van zandt2300@gaagle.xyz
#
# No match found in ike5340@email.apple
#
# No match found in 120987413@email.tech
#
# No match found in ziegler@hotmoille.hu
#
# No match found in van zandt@email.me
#
# Match found in tisler.monte@odul.gov
#  Name : Tisler, surname : Monte
# No match found in van zandt8519@odul.me
#
# No match found in victorquinn@gaagle.io
#
# No match found in lulloffhal@mail.bocode.net
#
# No match found in aaronebner@youhoo.apple
#
# Match found in fred.moore@gaagle.net
#  Name : Fred, surname : Moore
# No match found in adam3605@gaagle.io
#
# No match found in thompson@mail.adlp.hu
#
# No match found in stevewagle@napster.com
#
# No match found in montedeitz@napster.hu
#
# Match found in vanderpoel-adam@proton.gov
#  Name : Vanderpoel, surname : Adam
# Match found in orwig_john@email.org
#  Name : Orwig, surname : John
# No match found in roger@napster.apple
#
# No match found in edwarddeitz@gaagle.tech
#
# No match found in 273554425@proton.gov
#
# Match found in edward.darnell@proton.org
#  Name : Edward, surname : Darnell
# No match found in marknapier@youhoo.com
#
# No match found in paul635@mail.adlp.xyz
#
# Match found in upson.peter@gaagle.me
#  Name : Upson, surname : Peter
# Match found in john.stahl@email.xyz
#  Name : John, surname : Stahl
# Match found in duffman.aaron@proton.hu
#  Name : Duffman, surname : Aaron
# No match found in jenson@hotmoille.hu
#
# No match found in rogermcginnis@napster.tech
#
# No match found in soukup@belgaximus.gov
#
# No match found in soloman@odul.apple
#
# No match found in 877692701@napster.hu
#
# No match found in tandyaaron@ecoin.tech
#
# No match found in ingramthomas@youhoo.xyz
#
# No match found in aaron8129@belgaximus.apple
#
# No match found in vanderpoeljoe@mail.adlp.io
#
# No match found in fredmills@imail.net
#
# No match found in haljagtap@hotmoille.org
#
# No match found in larry.hancock@mail.bocode.xyz
#
# Match found in soloman_eastman@email.com
#  Name : Soloman, surname : Eastman
# No match found in montelewis@gaagle.org
#
# No match found in 631338425@mail.adlp.gov
#
# Match found in peter.mccord@gaagle.com
#  Name : Peter, surname : Mccord
# No match found in hylan@mail.bocode.apple
#
# No match found in roger@proton.io
#
# No match found in paiser@youhoo.gov
#
# Match found in schickowski-steve@belgaximus.gov
#  Name : Schickowski, surname : Steve
# No match found in ty@imail.gov
#
# No match found in roberts@youhoo.gov
#
# No match found in 958642438@email.net
#
# No match found in boyd3853@belgaximus.net
#
# Match found in soloman_nathan@youhoo.gov
#  Name : Soloman, surname : Nathan
# No match found in 92101346@proton.tech
#
# Match found in chambers.mark@napster.com
#  Name : Chambers, surname : Mark
# No match found in nuttleedward@gaagle.apple
#
# No match found in adamrice@ecoin.net
#
# No match found in fred937@odul.com
#
# No match found in ben@belgaximus.hu
#
# No match found in lepagemark@mail.adlp.xyz
#
# No match found in dan@gaagle.gov
#
# No match found in walterturco@imail.tech
#
# No match found in ebner_fred@mail.bocode.net
#
# No match found in danwagner@mail.bocode.gov
#
# No match found in jones206@mail.bocode.com
#
# No match found in steve.root@mail.adlp.net
#
# Match found in roger.fletcher@belgaximus.xyz
#  Name : Roger, surname : Fletcher
# No match found in casal.david@mail.bocode.tech
#
# No match found in adamziegler@youhoo.org
#
# No match found in 275056493@youhoo.xyz
#
# No match found in peterlewis@belgaximus.gov
#
# No match found in jack@imail.net
#
# No match found in george3788@gaagle.com
#
# No match found in seversonpaul@mail.adlp.xyz
#
# Match found in zeller.roger@youhoo.me
#  Name : Zeller, surname : Roger
# No match found in ottoschmitt@odul.org
#
# No match found in fietzer_cast@mail.bocode.tech
#
# Match found in tiernan.jack@ecoin.apple
#  Name : Tiernan, surname : Jack
# Match found in schutz_knutson@gaagle.gov
#  Name : Schutz, surname : Knutson
# No match found in matthew2395@mail.adlp.net
#
# Match found in hal.severson@youhoo.hu
#  Name : Hal, surname : Severson
# Match found in reyes-paul@imail.gov
#  Name : Reyes, surname : Paul
# Match found in mccord_ferry@odul.gov
#  Name : Mccord, surname : Ferry
# No match found in uddin2208@youhoo.me
#
# No match found in moody1342@mail.adlp.com
#
# No match found in roger6727@imail.me
#
# No match found in schlicht670@hotmoille.net
#
# No match found in steve@odul.xyz
#
# No match found in sawyer@napster.apple
#
# No match found in soulis2863@belgaximus.hu
#
# No match found in yates.steve@mail.adlp.io
#
# No match found in sonderling4257@email.org
#
# Match found in upson_paul@gaagle.org
#  Name : Upson, surname : Paul
# No match found in timtrebil@belgaximus.tech
#
# No match found in 104036307@ecoin.me
#
# No match found in frankupson@imail.apple
#
# No match found in fietzeralex@youhoo.hu
#
# No match found in solomanjohn@youhoo.apple
#
# No match found in peter6564@email.hu
#
# No match found in johnsen2199@gaagle.tech
#
# Match found in uflan-frank@belgaximus.apple
#  Name : Uflan, surname : Frank
# Match found in lepage_edward@ecoin.net
#  Name : Lepage, surname : Edward
# No match found in dugelman8872@odul.me
#
# No match found in carlvanderpoel@mail.adlp.apple
#
# Match found in vanderpoel_hydinger@odul.xyz
#  Name : Vanderpoel, surname : Hydinger
# No match found in ripka2789@email.io
#
# No match found in chambers.aaron@mail.adlp.com
#
# No match found in nathan2454@mail.adlp.xyz
#
# No match found in larry1596@imail.tech
#
# No match found in moorety@napster.io
#
# Match found in roger.fietzer@belgaximus.apple
#  Name : Roger, surname : Fietzer
# No match found in soulispeter@imail.io
#
# No match found in victorschmitt@mail.bocode.org
#
# No match found in ty3503@imail.apple
#
# Match found in lepage_ostrander@hotmoille.io
#  Name : Lepage, surname : Ostrander
# Match found in vanderpoel_dan@gaagle.net
#  Name : Vanderpoel, surname : Dan
# No match found in darnellty@gaagle.org
#
# Match found in kalleg_david@belgaximus.gov
#  Name : Kalleg, surname : David
# No match found in steve@odul.apple
#
# Match found in lulloff.matthew@proton.hu
#  Name : Lulloff, surname : Matthew
# No match found in chamberspaul@odul.com
#
# No match found in anderson845@mail.bocode.com
#
# No match found in quizoz_upson@mail.adlp.tech
#
# No match found in bencasal@odul.io
#
# Match found in vader_john@napster.org
#  Name : Vader, surname : John
# No match found in mark.lepage@mail.adlp.apple
#
# No match found in lepage6698@email.hu
#
# Match found in zeller_ziegler@ecoin.tech
#  Name : Zeller, surname : Ziegler
# No match found in walterschwager@email.io
#
# No match found in christensenty@napster.xyz
#
# Match found in severson_woo@proton.org
#  Name : Severson, surname : Woo
# No match found in vailjoe@imail.io
#
# Match found in tiernan-frank@napster.org
#  Name : Tiernan, surname : Frank
# Match found in dewalt_adam@proton.net
#  Name : Dewalt, surname : Adam
# No match found in rogertrebil@mail.bocode.gov
#
# No match found in ziegler8928@imail.net
#
# Match found in duffman-ben@hotmoille.hu
#  Name : Duffman, surname : Ben
# Match found in wakefield_edward@youhoo.tech
#  Name : Wakefield, surname : Edward
# No match found in dugelman_van zandt@gaagle.net
#
# No match found in nugent1331@proton.xyz
#
# Match found in frick-otto@hotmoille.hu
#  Name : Frick, surname : Otto
# Match found in celedon_severson@odul.me
#  Name : Celedon, surname : Severson
# Match found in ty.tiernan@odul.gov
#  Name : Ty, surname : Tiernan
# No match found in schmitt@imail.org
#
# No match found in aaronwagle@email.tech
#
# No match found in woo@hotmoille.io
#
# No match found in tim9542@hotmoille.tech
#
# No match found in john5694@email.me
#
# Match found in sagar_nathan@belgaximus.xyz
#  Name : Sagar, surname : Nathan
# Match found in larry.dinkins@proton.com
#  Name : Larry, surname : Dinkins
# Match found in severson.steve@imail.hu
#  Name : Severson, surname : Steve
# No match found in fredturco@odul.net
#
# No match found in victoringram@mail.adlp.apple
#
# No match found in edward@youhoo.com
#
# Match found in tisler-matthew@imail.me
#  Name : Tisler, surname : Matthew
# Match found in reyes.roger@ecoin.tech
#  Name : Reyes, surname : Roger
# Match found in reamer_tim@hotmoille.org
#  Name : Reamer, surname : Tim
# Match found in schlicht-carl@ecoin.net
#  Name : Schlicht, surname : Carl
# No match found in steve3131@email.tech
#
# No match found in wagner9136@gaagle.apple
#
# Match found in davis_bowers@belgaximus.me
#  Name : Davis, surname : Bowers
# No match found in edward9079@napster.net
#
# No match found in 283141330@gaagle.hu
#
# No match found in tyduffman@hotmoille.hu
#
# No match found in walterhydinger@ecoin.io
#
# No match found in ben9635@odul.apple
#
# Match found in vanderpoel.mark@odul.tech
#  Name : Vanderpoel, surname : Mark
# Match found in delorenzo.jack@napster.xyz
#  Name : Delorenzo, surname : Jack
# No match found in chapman-roger@mail.adlp.com
#
# Match found in nathan.woo@proton.org
#  Name : Nathan, surname : Woo
# No match found in victorvader@belgaximus.tech
#
# No match found in bateman1522@mail.bocode.net
#
# Match found in ben.irwin@email.net
#  Name : Ben, surname : Irwin
# No match found in fredhaworth@mail.bocode.io
#
# Match found in eastman_larry@napster.apple
#  Name : Eastman, surname : Larry
# Match found in sweeney_alex@hotmoille.hu
#  Name : Sweeney, surname : Alex
# Match found in hydinger_otto@email.apple
#  Name : Hydinger, surname : Otto
# No match found in peter2600@belgaximus.apple
#
# Match found in eastman_adam@imail.xyz
#  Name : Eastman, surname : Adam
# No match found in thomas@gaagle.com
#
# No match found in hal@napster.gov
#
# No match found in paulresnick@gaagle.me
#
# No match found in 682804922@ecoin.hu
#
# Match found in ziegler-alex@odul.me
#  Name : Ziegler, surname : Alex
# No match found in maki-frank@mail.adlp.hu
#
# No match found in myerspeter@youhoo.me
#
# No match found in fred67@youhoo.net
#
# No match found in edwardhoffman@napster.apple
#
# Match found in nuttle-monte@email.gov
#  Name : Nuttle, surname : Monte
# Match found in thompson_orwig@napster.com
#  Name : Thompson, surname : Orwig
# Match found in ike.stahl@hotmoille.apple
#  Name : Ike, surname : Stahl
# No match found in markhoffman@imail.org
#
# No match found in 669214282@imail.com
#
# No match found in hank@proton.com
#
# Match found in pettigrew_bauer@youhoo.hu
#  Name : Pettigrew, surname : Bauer
# Match found in nuttle_upson@ecoin.com
#  Name : Nuttle, surname : Upson
# No match found in vader_ty@mail.adlp.org
#
# No match found in danziegler@hotmoille.tech
#
# Match found in nugent_uddin@belgaximus.com
#  Name : Nugent, surname : Uddin
# Match found in alex.mccormack@hotmoille.com
#  Name : Alex, surname : Mccormack
# No match found in larry@youhoo.hu
#
# No match found in aaron735@mail.bocode.me
#
# No match found in deitzdan@imail.apple
#
# No match found in alexhesch@odul.gov
#
# No match found in dinkinscarl@napster.io
#
# No match found in aaronschwager@mail.adlp.gov
#
# No match found in edward@imail.tech
#
# Match found in ory-ty@ecoin.com
#  Name : Ory, surname : Ty
# No match found in dugelman_roger@mail.bocode.com
#
# No match found in 43720854@ecoin.net
#
# No match found in larryulrich@mail.adlp.apple
#
# No match found in tiernanotto@hotmoille.xyz
#
# Match found in christensen-ben@odul.io
#  Name : Christensen, surname : Ben
# No match found in 220923632@proton.xyz
#
# No match found in stahl_larry@mail.bocode.com
#
# Match found in vader_larry@belgaximus.io
#  Name : Vader, surname : Larry
# No match found in lepage@odul.io
#
# No match found in woofrank@youhoo.hu
#
# No match found in 413352781@imail.xyz
#
# No match found in walterschutz@imail.apple
#
# No match found in ike@proton.xyz
#
# No match found in tislerjohn@napster.org
#
# Match found in ebner_chapman@email.me
#  Name : Ebner, surname : Chapman
# Match found in jurgenson.mark@odul.net
#  Name : Jurgenson, surname : Mark
# No match found in 40053022@belgaximus.apple
#
# No match found in nathanhylan@gaagle.io
#
# No match found in carl1266@proton.me
#
# No match found in ortiz@gaagle.hu
#
# No match found in johnsen1400@mail.bocode.tech
#
# Match found in irwin_otto@proton.hu
#  Name : Irwin, surname : Otto
# No match found in ikechapman@youhoo.io
#
# No match found in walter@mail.bocode.net
#
# Match found in nathan.zeller@odul.me
#  Name : Nathan, surname : Zeller
# No match found in joeuddin@ecoin.me
#
# No match found in lawicki@gaagle.org
#
# No match found in casal9156@belgaximus.com
#
# No match found in resnick2754@youhoo.xyz
#
# Match found in ashwoon_hank@odul.io
#  Name : Ashwoon, surname : Hank
# No match found in jack3740@proton.xyz
#
# Match found in hal.casal@hotmoille.com
#  Name : Hal, surname : Casal
# Match found in jurgenson_dan@napster.hu
#  Name : Jurgenson, surname : Dan
# No match found in 393543398@proton.hu
#
# No match found in steve5769@proton.apple
#
# Match found in duffman_vanderpoel@odul.com
#  Name : Duffman, surname : Vanderpoel
# No match found in ramachandran1712@mail.adlp.io
#
# Match found in dugelman-adam@imail.tech
#  Name : Dugelman, surname : Adam
# No match found in 735354722@hotmoille.gov
#
# No match found in monteschiebel@odul.tech
#
# Match found in larry.miller@youhoo.tech
#  Name : Larry, surname : Miller
# Match found in lepage-peter@hotmoille.apple
#  Name : Lepage, surname : Peter
# No match found in duffmanedward@email.me
#
# Match found in tim.roberts@ecoin.xyz
#  Name : Tim, surname : Roberts
# Match found in schickowski.matthew@napster.com
#  Name : Schickowski, surname : Matthew
# No match found in steve@youhoo.gov
#
# Match found in duffman_weiss@proton.gov
#  Name : Duffman, surname : Weiss
# No match found in rogersty@hotmoille.hu
#
# No match found in paulchapman@imail.xyz
#
# No match found in adam.delorenzo@mail.adlp.hu
#
# No match found in bongardben@napster.tech
#
# Match found in knutson-walter@belgaximus.hu
#  Name : Knutson, surname : Walter
# Match found in ory_joe@belgaximus.com
#  Name : Ory, surname : Joe
# Match found in chambers-walter@ecoin.apple
#  Name : Chambers, surname : Walter
# Match found in cannon_ferro@ecoin.apple
#  Name : Cannon, surname : Ferro
# Match found in rice_soulis@ecoin.apple
#  Name : Rice, surname : Soulis
# No match found in 579097737@belgaximus.hu
#
# No match found in chambers_roberts@mail.adlp.xyz
#
# No match found in pettigrewfred@odul.net
#
# No match found in victorillingsworth@ecoin.org
#
# No match found in wagnercarl@proton.net
#
# No match found in illingsworth.roger@mail.adlp.gov
#
# No match found in fred@imail.io
#
# No match found in tapiajohn@mail.adlp.me
#
# No match found in christensen@belgaximus.hu
#
# No match found in vail@gaagle.com
#
# No match found in nathan@imail.hu
#
# No match found in tandy@mail.adlp.apple
#
# No match found in victorjones@napster.tech
#
# Match found in resnick.david@odul.apple
#  Name : Resnick, surname : David
# No match found in roger@proton.net
#
# Match found in resnick.thomas@imail.apple
#  Name : Resnick, surname : Thomas
# Match found in soukup_tim@odul.apple
#  Name : Soukup, surname : Tim
# No match found in hank@hotmoille.org
#
# No match found in victorfletcher@imail.tech
#
# Match found in schwager_pak@odul.tech
#  Name : Schwager, surname : Pak
# No match found in weinsteintim@proton.org
#
# No match found in fred2414@hotmoille.apple
#
# No match found in hesch1648@imail.tech
#
# Match found in weiss_walter@gaagle.com
#  Name : Weiss, surname : Walter
# No match found in ottoreamer@email.apple
#
# No match found in carl@mail.adlp.gov
#
# No match found in fietzer_kaskel@mail.bocode.me
#
# No match found in timbauer@ecoin.apple
#
# Match found in ike.reyes@belgaximus.gov
#  Name : Ike, surname : Reyes
# No match found in matthew@hotmoille.com
#
# No match found in reardon@gaagle.hu
#
# No match found in mccormack7946@youhoo.me
#
# No match found in matthew6993@hotmoille.org
#
# Match found in nelson-matthew@imail.hu
#  Name : Nelson, surname : Matthew
# No match found in peter.mccormack@mail.adlp.me
#
# No match found in delorenzo-larry@mail.adlp.org
#
# Match found in mcginnis.walter@email.io
#  Name : Mcginnis, surname : Walter
# No match found in edward3639@mail.bocode.apple
#
# No match found in mark2192@youhoo.xyz
#
# No match found in dan@hotmoille.tech
#
# No match found in nuttlety@gaagle.gov
#
# No match found in victortisler@youhoo.com
#
# Match found in tisler_cannon@youhoo.apple
#  Name : Tisler, surname : Cannon
# No match found in otto.jurgenson@mail.adlp.me
#
# No match found in jacksolberg@gaagle.me
#
# Match found in nathan.vanderpoel@belgaximus.tech
#  Name : Nathan, surname : Vanderpoel
# Match found in fletcher_duffman@ecoin.com
#  Name : Fletcher, surname : Duffman
# Match found in dugan_ortiz@hotmoille.io
#  Name : Dugan, surname : Ortiz
# Match found in anderson_dewalt@odul.me
#  Name : Anderson, surname : Dewalt
# No match found in adampak@hotmoille.net
#
# Match found in peter.norquist@napster.net
#  Name : Peter, surname : Norquist
# No match found in yang@imail.net
#
# No match found in alex7627@youhoo.gov
#
# No match found in ben@napster.xyz
#
# Match found in ferry-walter@imail.tech
#  Name : Ferry, surname : Walter
# No match found in weiss9401@youhoo.xyz
#
# Match found in haworth_steve@youhoo.gov
#  Name : Haworth, surname : Steve
# No match found in ulrich9331@email.org
#
# Match found in baxster.mark@email.net
#  Name : Baxster, surname : Mark
# No match found in dugelman2727@odul.xyz
#
# Match found in yates_hal@odul.net
#  Name : Yates, surname : Hal
# No match found in otto1543@youhoo.gov
#
# Match found in bateman_joe@odul.apple
#  Name : Bateman, surname : Joe
# No match found in larryhoffman@belgaximus.tech
#
# No match found in celedonmatthew@napster.net
#
# No match found in victorrogers@gaagle.net
#
# Match found in ashwoon_ben@napster.net
#  Name : Ashwoon, surname : Ben
# No match found in van zandt_deitz@belgaximus.xyz
#
# No match found in 711978855@email.org
#
# No match found in delorenzo@belgaximus.xyz
#
# Match found in zeller_john@napster.hu
#  Name : Zeller, surname : John
# No match found in olson@odul.gov
#
# No match found in aaronmiller@mail.adlp.gov
#
# No match found in bensoukup@proton.me
#
# No match found in sweeneytim@ecoin.gov
#
# No match found in joe@proton.hu
#
# No match found in doran@proton.tech
#
# No match found in otto@hotmoille.gov
#
# No match found in frankchristensen@odul.me
#
# No match found in 524504262@odul.me
#
# No match found in tim3793@gaagle.io
#
# No match found in otto815@email.me
#
# Match found in sweeney.carl@gaagle.net
#  Name : Sweeney, surname : Carl
# Match found in knutson_trebil@email.me
#  Name : Knutson, surname : Trebil
# No match found in hank.nuttle@mail.adlp.me
#
# Match found in kalleg-tim@gaagle.gov
#  Name : Kalleg, surname : Tim
# No match found in ikecast@mail.adlp.apple
#
# Match found in jack.weinstein@email.apple
#  Name : Jack, surname : Weinstein
# No match found in myers_ramachandran@mail.bocode.io
#
# No match found in victor@proton.hu
#
# No match found in hancockcarl@napster.com
#
# Match found in schlicht.dan@email.tech
#  Name : Schlicht, surname : Dan
# No match found in tisler3297@belgaximus.tech
#
# No match found in steve6502@email.net
#
# No match found in frank5506@imail.apple
#
# Match found in schwager_joe@napster.org
#  Name : Schwager, surname : Joe
# Match found in dugelman-jack@hotmoille.net
#  Name : Dugelman, surname : Jack
# No match found in weiss5261@email.tech
#
# No match found in dantrusela@odul.org
#
# Match found in leisinger_walter@hotmoille.org
#  Name : Leisinger, surname : Walter
# No match found in roger4965@odul.net
#
# Match found in mccormack_ike@youhoo.hu
#  Name : Mccormack, surname : Ike
# No match found in jackortiz@imail.com
#
# No match found in walter@mail.bocode.xyz
#
# Match found in ferro_peter@ecoin.apple
#  Name : Ferro, surname : Peter
# No match found in ikemyers@mail.adlp.io
#
# No match found in schmitt@imail.apple
#
# Match found in yates.thomas@belgaximus.org
#  Name : Yates, surname : Thomas
# No match found in schutzike@ecoin.tech
#
# No match found in upson@hotmoille.hu
#
# Match found in schlicht.monte@hotmoille.com
#  Name : Schlicht, surname : Monte
# No match found in upson@youhoo.com
#
# No match found in 525072400@proton.tech
#
# Match found in jurgenson_trusela@odul.me
#  Name : Jurgenson, surname : Trusela
# No match found in georgeturco@imail.hu
#
# No match found in hank5891@mail.adlp.apple
#
# Match found in weiss-hank@proton.io
#  Name : Weiss, surname : Hank
# No match found in jenson9642@proton.io
#
# No match found in thomascaswell@napster.io
#
# No match found in thomaskalleg@ecoin.xyz
#
# Match found in bowers.steve@napster.io
#  Name : Bowers, surname : Steve
# No match found in victorresnick@proton.org
#
# No match found in walter8082@mail.adlp.xyz
#
# Match found in sellon_roger@proton.hu
#  Name : Sellon, surname : Roger
# No match found in peter@hotmoille.com
#
# No match found in victor2700@napster.xyz
#
# Match found in deitz-edward@belgaximus.net
#  Name : Deitz, surname : Edward
# No match found in 38460014@mail.adlp.io
#
# Match found in hesch_mills@ecoin.org
#  Name : Hesch, surname : Mills
# No match found in frankwoo@napster.gov
#
# No match found in van zandt_soloman@belgaximus.me
#
# Match found in ulrich_carl@belgaximus.hu
#  Name : Ulrich, surname : Carl
# No match found in adam@mail.adlp.com
#
# No match found in hoffman@hotmoille.hu
#
# No match found in zellersteve@napster.io
#
# No match found in jonesthomas@email.tech
#
# Match found in jagtap_victor@email.gov
#  Name : Jagtap, surname : Victor
# No match found in reyes3325@youhoo.gov
#
# No match found in schickowski7190@odul.tech
#
# No match found in irwin@odul.hu
#
# Match found in moore_edward@youhoo.org
#  Name : Moore, surname : Edward
# Match found in tisler_fred@imail.apple
#  Name : Tisler, surname : Fred
# No match found in thomas@email.xyz
#
# No match found in alexcataldi@napster.org
#
# No match found in tim@mail.bocode.apple
#
# No match found in hankulrich@belgaximus.hu
#
# No match found in otto.reamer@mail.adlp.net
#
# No match found in rogerchambers@mail.bocode.io
#
# No match found in alexdavidson@mail.adlp.net
#
# Match found in peter.moody@proton.io
#  Name : Peter, surname : Moody
# Match found in ben.weinstein@odul.apple
#  Name : Ben, surname : Weinstein
# Match found in davidson_jack@youhoo.xyz
#  Name : Davidson, surname : Jack
# No match found in jacksellon@napster.io
#
# No match found in cataldiedward@hotmoille.io
#
# Match found in sellon.jack@ecoin.net
#  Name : Sellon, surname : Jack
# No match found in 748522766@gaagle.xyz
#
# No match found in victorsweeney@odul.tech
#
# Match found in nelson-matthew@belgaximus.me
#  Name : Nelson, surname : Matthew
# No match found in johnmoody@imail.xyz
#
# Match found in peter.sandstrom@napster.xyz
#  Name : Peter, surname : Sandstrom
# No match found in montelulloff@email.io
#
# No match found in andersonhal@odul.apple
#
# Match found in napier_hank@belgaximus.hu
#  Name : Napier, surname : Hank
# No match found in moodygeorge@proton.net
#
# No match found in peter4809@email.net
#
# No match found in marknapier@proton.io
#
# Match found in darnell_roger@hotmoille.net
#  Name : Darnell, surname : Roger
# No match found in george@belgaximus.gov
#
# Match found in tim.weinstein@odul.io
#  Name : Tim, surname : Weinstein
# Match found in pak_roger@proton.com
#  Name : Pak, surname : Roger
# No match found in georgecasal@hotmoille.tech
#
# Match found in trusela-jack@email.net
#  Name : Trusela, surname : Jack
# No match found in thomasvan zandt@email.tech
#
# Match found in fred.martin@youhoo.apple
#  Name : Fred, surname : Martin
# No match found in alex@proton.apple
#
# Match found in dan.ventotla@proton.gov
#  Name : Dan, surname : Ventotla
# Match found in dewalt_joe@email.com
#  Name : Dewalt, surname : Joe
# Match found in celedon_hesch@youhoo.net
#  Name : Celedon, surname : Hesch
# No match found in ty8684@odul.apple
#
# Match found in nuttle_yang@youhoo.hu
#  Name : Nuttle, surname : Yang
# Match found in hal.rice@napster.com
#  Name : Hal, surname : Rice
# No match found in 821663824@odul.apple
#
# Match found in mccord.fred@proton.apple
#  Name : Mccord, surname : Fred
# No match found in orwig@ecoin.xyz
#
# No match found in 857071926@mail.bocode.net
#
# No match found in turcolarry@gaagle.hu
#
# Match found in mcginnis_aaron@email.com
#  Name : Mcginnis, surname : Aaron
# No match found in johnpettigrew@proton.hu
#
# Match found in root-edward@gaagle.hu
#  Name : Root, surname : Edward
# Match found in hal.yocum@email.apple
#  Name : Hal, surname : Yocum
# No match found in monteschuster@belgaximus.gov
#
# Match found in fietzer_mark@gaagle.tech
# ...
# Match found in yates_thomas@ecoin.xyz
#  Name : Yates, surname : Thomas
# Match found in knutson_thomas@email.com
#  Name : Knutson, surname : Thomas
# Match found in davis.monte@hotmoille.net
#  Name : Davis, surname : Monte
# Match found in vader_alex@odul.xyz
#  Name : Vader, surname : Alex
# No match found in nuttle1626@imail.hu
#
# No match found in 738731613@email.io
#
# Match found in hesch.hank@email.me
#  Name : Hesch, surname : Hank
# No match found in monte6198@imail.me
#
# No match found in alexhydinger@gaagle.gov
#
# Match found in caswell-aaron@odul.xyz
#  Name : Caswell, surname : Aaron
# No match found in dancasal@mail.bocode.me
#
# Match found in schuster_tiernan@email.xyz
#  Name : Schuster, surname : Tiernan
# No match found in victorkeller@proton.net
#
# Match found in illingsworth.monte@belgaximus.apple
#  Name : Illingsworth, surname : Monte
# No match found in jones@mail.bocode.net
#
# No match found in peter@belgaximus.net
#
# No match found in hoffman9254@odul.tech
#
# No match found in sandstrom6021@belgaximus.gov
#
# No match found in 260123181@mail.adlp.xyz
#
# Match found in moody_lawless@youhoo.tech
#  Name : Moody, surname : Lawless
# No match found in 622921665@belgaximus.org
#
# No match found in wagner@ecoin.me
#
# No match found in 498202212@odul.tech
#
# No match found in thompson2886@belgaximus.org
#
# No match found in alexfrick@email.xyz
#
# Match found in zeller.matthew@imail.com
#  Name : Zeller, surname : Matthew
# No match found in thomasjagtap@proton.hu
#
# Match found in stahl_solberg@proton.hu
#  Name : Stahl, surname : Solberg
# No match found in resnick@youhoo.me
#
# Match found in tisler-larry@hotmoille.me
#  Name : Tisler, surname : Larry
# No match found in 881606408@imail.io
#
# No match found in hank4616@proton.gov
#
# Match found in thomas.reamer@odul.hu
#  Name : Thomas, surname : Reamer
# No match found in turco@hotmoille.tech
#
# Match found in jones-roger@gaagle.org
#  Name : Jones, surname : Roger
# Match found in matthew.doran@odul.hu
#  Name : Matthew, surname : Doran
# Match found in frick_steve@napster.gov
#  Name : Frick, surname : Steve
# No match found in edwarddinkins@imail.com
#
# No match found in 35834059@proton.com
#
# No match found in paul7873@ecoin.com
#
# Match found in upson_quinn@youhoo.tech
#  Name : Upson, surname : Quinn
# No match found in sellon.frank@mail.bocode.org
#
# No match found in peteryocum@proton.io
#
# Match found in rice-aaron@ecoin.tech
#  Name : Rice, surname : Aaron
# No match found in 714215742@mail.bocode.org
#
# No match found in 200912703@youhoo.org
#
# No match found in 537912928@mail.adlp.xyz
#
# No match found in hank2763@imail.io
#
# No match found in roger4911@hotmoille.apple
#
# No match found in nathanbaxster@mail.adlp.hu
#
# No match found in thompsonlarry@email.net
#
# No match found in franklepage@mail.bocode.me
#
# Match found in ebner_casal@hotmoille.com
#  Name : Ebner, surname : Casal
# No match found in moodyroger@ecoin.com
#
# Match found in maki-alex@email.gov
#  Name : Maki, surname : Alex
# Match found in johnson-hank@ecoin.apple
#  Name : Johnson, surname : Hank
# Match found in delorenzo_adam@hotmoille.org
#  Name : Delorenzo, surname : Adam
# Match found in dan.delorenzo@proton.xyz
#  Name : Dan, surname : Delorenzo
# No match found in knutsondavid@napster.me
#
# No match found in hal2231@hotmoille.me
#
# Match found in quinn_aikin@hotmoille.net
#  Name : Quinn, surname : Aikin
# No match found in trebilroger@belgaximus.com
#
# No match found in tiernanmark@odul.apple
#
# Match found in olson.george@odul.tech
#  Name : Olson, surname : George
# No match found in reamer@imail.hu
#
# No match found in haworth9991@email.gov
#
# No match found in robertsmark@imail.gov
#
# No match found in jack@belgaximus.com
#
# No match found in trussel@youhoo.hu
#
# No match found in mcginnis_orwig@mail.adlp.com
#
# No match found in jackupson@proton.xyz
#
# No match found in nugent6976@napster.com
#
# Match found in martin_kaskel@hotmoille.gov
#  Name : Martin, surname : Kaskel
# No match found in davidturco@mail.adlp.net
#
# No match found in halquinn@belgaximus.com
#
# Match found in vail.frank@hotmoille.apple
#  Name : Vail, surname : Frank
# No match found in nuttlesteve@odul.me
#
# No match found in vail@mail.adlp.tech
#
# Match found in nathan.yocum@ecoin.apple
#  Name : Nathan, surname : Yocum
# No match found in victorknutson@proton.io
#
# No match found in kaskel@ecoin.me
#
# No match found in 72032888@email.me
#
# Match found in joe.nuttle@youhoo.io
#  Name : Joe, surname : Nuttle
# No match found in nathan3403@napster.apple
#
# No match found in aaron@imail.me
#
# No match found in chapman-monte@mail.adlp.gov
#
# No match found in aaron1573@odul.net
#
# No match found in benmoody@proton.io
#
# No match found in van zandt9356@youhoo.gov
#
# Match found in trebil-aaron@ecoin.net
#  Name : Trebil, surname : Aaron
# No match found in 916085653@napster.hu
#
# Match found in knutson.tim@napster.io
#  Name : Knutson, surname : Tim
# Match found in schickowski_tapia@hotmoille.tech
#  Name : Schickowski, surname : Tapia
# No match found in john5147@napster.gov
#
# No match found in fredlawicki@hotmoille.me
#
# No match found in hesch@mail.bocode.tech
#
# No match found in nathan@ecoin.net
#
# Match found in reardon.ben@ecoin.net
#  Name : Reardon, surname : Ben
# No match found in edwardanderson@mail.bocode.io
#
# No match found in kellerhal@proton.tech
#
# Match found in kalleg_nathan@ecoin.hu
#  Name : Kalleg, surname : Nathan
# Match found in roger.dinkins@proton.io
#  Name : Roger, surname : Dinkins
# Match found in johnsen_cataldi@napster.io
#  Name : Johnsen, surname : Cataldi
# Match found in hal.wagner@imail.com
#  Name : Hal, surname : Wagner
# No match found in bongard@hotmoille.tech
#
# No match found in mccord@mail.bocode.apple
#
# Match found in bowers_ulrich@email.me
#  Name : Bowers, surname : Ulrich
# No match found in nelsonroger@gaagle.xyz
#
# No match found in stevevan zandt@email.hu
#
# Match found in lewis_ortiz@proton.me
#  Name : Lewis, surname : Ortiz
# Match found in reyes_steve@gaagle.apple
#  Name : Reyes, surname : Steve
# Match found in martin.edward@odul.org
#  Name : Martin, surname : Edward
# No match found in roberts_walter@mail.bocode.hu
#
# Match found in davidson-victor@napster.io
#  Name : Davidson, surname : Victor
# No match found in ike1526@ecoin.net
#
# No match found in 76134991@imail.hu
#
# Match found in aaron.pak@imail.tech
#  Name : Aaron, surname : Pak
# No match found in 819378036@proton.com
#
# No match found in ty9361@gaagle.xyz
#
# No match found in frankwoo@belgaximus.hu
#
# No match found in stevevan zandt@email.apple
#
# No match found in solberg@belgaximus.hu
#
# Match found in stahl-adam@hotmoille.net
#  Name : Stahl, surname : Adam
# No match found in turco@odul.apple
#
# No match found in ashwoonthomas@odul.gov
#
# Match found in kaskel.tim@youhoo.org
#  Name : Kaskel, surname : Tim
# No match found in larry8418@belgaximus.me
#
# No match found in tandyty@email.xyz
#
# Match found in bauer_ripka@odul.xyz
#  Name : Bauer, surname : Ripka
# Match found in moody-victor@ecoin.com
#  Name : Moody, surname : Victor
# No match found in 866926931@ecoin.org
#
# No match found in van zandt_paul@proton.net
#
# Match found in hylan_john@ecoin.hu
#  Name : Hylan, surname : John
# Match found in hoffman_darnell@napster.org
#  Name : Hoffman, surname : Darnell
# No match found in sonderling7306@belgaximus.gov
#
# No match found in mills_delorenzo@mail.adlp.org
#
# No match found in hank@email.gov
#
# Match found in johnson_joe@email.hu
#  Name : Johnson, surname : Joe
# No match found in lawicki@gaagle.tech
#
# Match found in johnson_yates@gaagle.gov
#  Name : Johnson, surname : Yates
# Match found in zeller_ty@gaagle.me
#  Name : Zeller, surname : Ty
# No match found in thomascasal@imail.net
#
# Match found in wagle.dan@hotmoille.net
#  Name : Wagle, surname : Dan
# No match found in reamer_jones@mail.bocode.hu
#
# No match found in carl3060@proton.tech
#
# No match found in roger6892@imail.hu
#
# No match found in petervader@ecoin.io
#
# No match found in thompson@mail.adlp.org
#
# No match found in waglehal@belgaximus.io
#
# No match found in paulhydinger@proton.com
#
# Match found in tapia_john@gaagle.xyz
#  Name : Tapia, surname : John
# No match found in larry@mail.adlp.net
#
# No match found in andersonedward@ecoin.xyz
#
# No match found in timsellon@hotmoille.com
#
# Match found in tim.fietzer@gaagle.net
#  Name : Tim, surname : Fietzer
# No match found in pakalex@gaagle.com
#
# No match found in markpak@proton.io
#
# No match found in victordinkins@ecoin.org
#
# Match found in kaskel_duffman@imail.me
#  Name : Kaskel, surname : Duffman
# No match found in paul9959@email.gov
#
# Match found in ike.maki@imail.me
#  Name : Ike, surname : Maki
# No match found in moorefrank@mail.bocode.apple
#
# No match found in 406392428@belgaximus.hu
#
# Match found in ory_nugent@email.xyz
#  Name : Ory, surname : Nugent
# No match found in solomangeorge@hotmoille.apple
#
# Match found in bateman_weinstein@belgaximus.gov
#  Name : Bateman, surname : Weinstein
# No match found in zeaser@ecoin.gov
#
# No match found in ulrichty@odul.hu
#
# No match found in irwin-paul@mail.bocode.xyz
#
# No match found in alexmcginnis@belgaximus.org
#
# No match found in cataldi.tim@mail.adlp.tech
#
# No match found in halrice@hotmoille.hu
#
# Match found in nelson.steve@imail.hu
#  Name : Nelson, surname : Steve
# Match found in vail_chapman@youhoo.net
#  Name : Vail, surname : Chapman
# No match found in schiebelthomas@ecoin.hu
#
# Match found in ike.hancock@imail.apple
#  Name : Ike, surname : Hancock
# No match found in roger@belgaximus.hu
#
# Match found in nugent_fletcher@ecoin.hu
#  Name : Nugent, surname : Fletcher
# No match found in maki8692@imail.gov
#
# No match found in adam@email.tech
#
# No match found in roger.maki@mail.bocode.apple
#
# Match found in sellon-david@ecoin.com
#  Name : Sellon, surname : David
# No match found in adam@hotmoille.io
#
# No match found in thomasyates@odul.com
#
# Match found in celedon_walter@napster.hu
#  Name : Celedon, surname : Walter
# No match found in kassing4495@proton.io
#
# Match found in boyd_george@odul.io
#  Name : Boyd, surname : George
# Match found in bowers_ebner@email.xyz
#  Name : Bowers, surname : Ebner
# No match found in jack9352@odul.tech
#
# No match found in lewisdan@youhoo.net
#
# Match found in schmitt-roger@napster.tech
#  Name : Schmitt, surname : Roger
# No match found in mccormackmark@hotmoille.net
#
# No match found in timbauer@odul.org
#
# No match found in roger349@mail.adlp.net
#
# Match found in reamer_rogers@proton.hu
#  Name : Reamer, surname : Rogers
# No match found in soulisfred@belgaximus.gov
#
# Match found in vader.tim@hotmoille.xyz
#  Name : Vader, surname : Tim
# No match found in ory.hal@mail.bocode.apple
#
# No match found in wagnerthomas@youhoo.tech
#
# No match found in adamjagtap@hotmoille.apple
#
# Match found in paul.reamer@napster.com
#  Name : Paul, surname : Reamer
# No match found in adam@belgaximus.io
#
# No match found in ty@email.tech
#
# No match found in edward@email.net
#
# No match found in doran2286@imail.org
#
# No match found in irwinhal@belgaximus.tech
#
# No match found in tyschwager@odul.tech
#
# No match found in georgemills@imail.apple
#
# No match found in wagle389@odul.com
#
# No match found in edwardferro@hotmoille.net
#
# No match found in adamostrander@hotmoille.gov
#
# Match found in keller-ty@youhoo.org
#  Name : Keller, surname : Ty
# No match found in 258546748@imail.org
#
# No match found in bencaswell@imail.gov
#
# No match found in steve1862@hotmoille.com
#
# No match found in halturco@email.hu
#
# Match found in tiernan_casal@email.com
#  Name : Tiernan, surname : Casal
# No match found in solberg4139@mail.adlp.tech
#
# Match found in davidson-otto@youhoo.com
#  Name : Davidson, surname : Otto
# No match found in alexdoran@napster.org
#
# No match found in thomas@mail.adlp.me
#
# No match found in monte.upson@mail.adlp.com
#
# Match found in frick_cannon@gaagle.tech
#  Name : Frick, surname : Cannon
# No match found in otto@email.apple
#
# No match found in schutz-steve@mail.bocode.xyz
#
# No match found in ikenorquist@mail.bocode.org
#
# No match found in hal@email.tech
#
# Match found in ulrich.thomas@odul.io
#  Name : Ulrich, surname : Thomas
# No match found in vader_casal@mail.bocode.org
#
# No match found in aaron@mail.bocode.org
#
# Match found in anderson_aaron@odul.me
#  Name : Anderson, surname : Aaron
# No match found in aikin8186@mail.bocode.hu
#
# Match found in hoffman_victor@imail.tech
#  Name : Hoffman, surname : Victor
# No match found in larrythompson@imail.apple
#
# No match found in ebnerjohn@gaagle.apple
#
# Match found in frank.nelson@proton.net
#  Name : Frank, surname : Nelson
# Match found in ebner_reamer@email.me
#  Name : Ebner, surname : Reamer
# Match found in trusela_paul@imail.me
#  Name : Trusela, surname : Paul
# No match found in dinkinsalex@email.io
#
# No match found in jack3083@belgaximus.gov
#
# No match found in casal@youhoo.gov
#
# No match found in fred@imail.me
#
# No match found in davisgeorge@napster.tech
#
# No match found in jagtap@odul.com
#
# No match found in joe1068@mail.adlp.tech
#
# No match found in wagner.roger@mail.adlp.apple
#
# No match found in fredvalente@gaagle.me
#
# Match found in hylan.carl@hotmoille.gov
#  Name : Hylan, surname : Carl
# No match found in 270804951@napster.org
#
# No match found in uddin1875@napster.apple
#
# Match found in turco.carl@belgaximus.tech
#  Name : Turco, surname : Carl
# No match found in hoffman@gaagle.apple
#
# Match found in joe.rogers@gaagle.xyz
#  Name : Joe, surname : Rogers
# Match found in schmitt_larry@odul.gov
#  Name : Schmitt, surname : Larry
# No match found in 879442014@mail.bocode.tech
#
# No match found in carlsoloman@ecoin.com
#
# No match found in nathan6115@imail.me
#
# No match found in frank@imail.io
#
# Match found in norquist_steve@belgaximus.com
#  Name : Norquist, surname : Steve
# No match found in delorenzo_peter@mail.adlp.xyz
#
# No match found in paul@hotmoille.gov
#
# No match found in orwig@odul.me
#
# Match found in dinkins-adam@imail.tech
#  Name : Dinkins, surname : Adam
# No match found in tislerdan@hotmoille.tech
#
# No match found in edward6174@imail.me
#
# No match found in montepettigrew@hotmoille.hu
#
# No match found in schutzlarry@odul.net
#
# No match found in zeasertim@proton.tech
#
# Match found in walter.kassing@odul.tech
#  Name : Walter, surname : Kassing
# Match found in ferro.david@gaagle.tech
#  Name : Ferro, surname : David
# Match found in schmitt_schiebel@belgaximus.gov
#  Name : Schmitt, surname : Schiebel
# No match found in ikethompson@mail.bocode.tech
#
# Match found in martin.ben@imail.me
#  Name : Martin, surname : Ben
# No match found in benventotla@youhoo.org
#
# Match found in ziegler_soloman@imail.io
#  Name : Ziegler, surname : Soloman
# Match found in davidson_rogers@belgaximus.xyz
#  Name : Davidson, surname : Rogers
# No match found in george@proton.org
#
# No match found in ramachandran431@napster.hu
#
# No match found in paulostrander@youhoo.xyz
#
# No match found in tyseverson@hotmoille.hu
#
# No match found in edwardortiz@hotmoille.tech
#
# No match found in hal5999@email.org
#
# Match found in christensen-david@odul.hu
#  Name : Christensen, surname : David
# No match found in mark@mail.adlp.me
#
# Match found in bongard-paul@gaagle.xyz
#  Name : Bongard, surname : Paul
# No match found in moody3417@ecoin.gov
#
# Match found in trebil_bowers@proton.org
#  Name : Trebil, surname : Bowers
# No match found in pak9267@ecoin.hu
#
# No match found in 883886499@youhoo.io
#
# No match found in peterknutson@gaagle.hu
#
# No match found in mark@belgaximus.gov
#
# No match found in 660694516@napster.apple
#
# No match found in larry@belgaximus.gov
#
# Match found in wagner-otto@ecoin.apple
#  Name : Wagner, surname : Otto
# No match found in ripka1096@email.apple
#
# Match found in bowers.otto@proton.gov
#  Name : Bowers, surname : Otto
# No match found in peter2859@mail.adlp.net
#
# Match found in ulrich_fred@imail.tech
#  Name : Ulrich, surname : Fred
# Match found in dugelman_carl@youhoo.io
#  Name : Dugelman, surname : Carl
# No match found in 801140752@email.net
#
# No match found in schutz_otto@mail.adlp.hu
#
# Match found in vader-larry@hotmoille.me
#  Name : Vader, surname : Larry
# Match found in jurgenson.aaron@napster.io
#  Name : Jurgenson, surname : Aaron
# Match found in stahl_ty@gaagle.tech
#  Name : Stahl, surname : Ty
# No match found in lawickimatthew@gaagle.tech
#
# Match found in kassing-victor@gaagle.io
#  Name : Kassing, surname : Victor
# No match found in halbongard@hotmoille.tech
#
# Match found in soukup.roger@youhoo.com
#  Name : Soukup, surname : Roger
# No match found in 733095700@mail.adlp.io
#
# Match found in jack.sweeney@hotmoille.org Name : Jack, surname : Sweeney

# %%
# Open the file and read its contents line by line
with open("./data/mail.txt") as file:
    list_mail = file.readlines()  # This gives you a list of lines

# Define the corrected regex pattern
pattern = r"^(?P<name>\w+)[._-](?P<last_name>\w+)@(?P<operator>\w+)(?P<zone>(\.\w+)+)$"
pattern2 = r"^(?P<name>\w+)@(?P<operator>\w+)(?P<zone>(\.\w+)+)$"

# Loop through each line (email)
for email in list_mail:
    email = email.strip()  # Remove any extra whitespace or newline characters
    research_email = re.search(pattern, email)
    research_email2 = re.search(pattern2, email)
    
    if research_email:
        print(f"Match found for {email}: {research_email.groupdict()}")
    elif research_email2:
        print(f"Match found for {email}: {research_email2.groupdict()}")
    else:
        print(f"No match for: {email}")
# Out:
# Match found for vogal-roger@mail.adlp.tech: {'name': 'vogal', 'last_name': 'roger', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for aikin.joe@odul.xyz: {'name': 'aikin', 'last_name': 'joe', 'operator': 'odul', 'zone': '.xyz'}
# Match found for moore@imail.gov: {'name': 'moore', 'operator': 'imail', 'zone': '.gov'}
# Match found for halknutson@email.xyz: {'name': 'halknutson', 'operator': 'email', 'zone': '.xyz'}
# Match found for alexnorquist@proton.com: {'name': 'alexnorquist', 'operator': 'proton', 'zone': '.com'}
# Match found for matthewlulloff@mail.adlp.me: {'name': 'matthewlulloff', 'operator': 'mail', 'zone': '.adlp.me'}
# Match found for jenson-thomas@belgaximus.org: {'name': 'jenson', 'last_name': 'thomas', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for mark4451@mail.bocode.gov: {'name': 'mark4451', 'operator': 'mail', 'zone': '.bocode.gov'}
# Match found for monte.hylan@belgaximus.net: {'name': 'monte', 'last_name': 'hylan', 'operator': 'belgaximus', 'zone': '.net'}
# Match found for dan80@mail.adlp.com: {'name': 'dan80', 'operator': 'mail', 'zone': '.adlp.com'}
# Match found for schmitt-steve@napster.org: {'name': 'schmitt', 'last_name': 'steve', 'operator': 'napster', 'zone': '.org'}
# Match found for knutsondan@belgaximus.org: {'name': 'knutsondan', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for lepage@gaagle.xyz: {'name': 'lepage', 'operator': 'gaagle', 'zone': '.xyz'}
# Match found for chapman_ben@napster.hu: {'name': 'chapman', 'last_name': 'ben', 'operator': 'napster', 'zone': '.hu'}
# Match found for upson1544@youhoo.hu: {'name': 'upson1544', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for 552966959@belgaximus.hu: {'name': '552966959', 'operator': 'belgaximus', 'zone': '.hu'}
# Match found for soloman_ziegler@email.tech: {'name': 'soloman', 'last_name': 'ziegler', 'operator': 'email', 'zone': '.tech'}
# Match found for ortiz.mark@napster.me: {'name': 'ortiz', 'last_name': 'mark', 'operator': 'napster', 'zone': '.me'}
# Match found for ashwoon_hank@imail.io: {'name': 'ashwoon', 'last_name': 'hank', 'operator': 'imail', 'zone': '.io'}
# Match found for pettigrew@proton.hu: {'name': 'pettigrew', 'operator': 'proton', 'zone': '.hu'}
# Match found for doranedward@napster.net: {'name': 'doranedward', 'operator': 'napster', 'zone': '.net'}
# Match found for mills_joe@imail.xyz: {'name': 'mills', 'last_name': 'joe', 'operator': 'imail', 'zone': '.xyz'}
# Match found for valente_alex@mail.adlp.net: {'name': 'valente', 'last_name': 'alex', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for yang@email.hu: {'name': 'yang', 'operator': 'email', 'zone': '.hu'}
# Match found for ike@ecoin.io: {'name': 'ike', 'operator': 'ecoin', 'zone': '.io'}
# Match found for hankshaffer@mail.bocode.io: {'name': 'hankshaffer', 'operator': 'mail', 'zone': '.bocode.io'}
# Match found for larrytrebil@email.org: {'name': 'larrytrebil', 'operator': 'email', 'zone': '.org'}
# Match found for davis_ike@odul.io: {'name': 'davis', 'last_name': 'ike', 'operator': 'odul', 'zone': '.io'}
# Match found for davidsonhal@hotmoille.apple: {'name': 'davidsonhal', 'operator': 'hotmoille', 'zone': '.apple'}
# Match found for john8733@youhoo.com: {'name': 'john8733', 'operator': 'youhoo', 'zone': '.com'}
# Match found for johnfletcher@youhoo.me: {'name': 'johnfletcher', 'operator': 'youhoo', 'zone': '.me'}
# Match found for cataldi_larry@napster.com: {'name': 'cataldi', 'last_name': 'larry', 'operator': 'napster', 'zone': '.com'}
# Match found for rogerfietzer@imail.apple: {'name': 'rogerfietzer', 'operator': 'imail', 'zone': '.apple'}
# Match found for edward4185@gaagle.gov: {'name': 'edward4185', 'operator': 'gaagle', 'zone': '.gov'}
# Match found for hancock_matthew@belgaximus.gov: {'name': 'hancock', 'last_name': 'matthew', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for solberg_cast@gaagle.apple: {'name': 'solberg', 'last_name': 'cast', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for vader-jack@youhoo.hu: {'name': 'vader', 'last_name': 'jack', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for georgepak@gaagle.me: {'name': 'georgepak', 'operator': 'gaagle', 'zone': '.me'}
# Match found for caswell-hal@ecoin.io: {'name': 'caswell', 'last_name': 'hal', 'operator': 'ecoin', 'zone': '.io'}
# Match found for ike@ecoin.com: {'name': 'ike', 'operator': 'ecoin', 'zone': '.com'}
# Match found for tapia_quinn@gaagle.io: {'name': 'tapia', 'last_name': 'quinn', 'operator': 'gaagle', 'zone': '.io'}
# Match found for 795419860@imail.tech: {'name': '795419860', 'operator': 'imail', 'zone': '.tech'}
# Match found for chambers_johnsen@mail.bocode.me: {'name': 'chambers', 'last_name': 'johnsen', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for jack@gaagle.apple: {'name': 'jack', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for joe@ecoin.tech: {'name': 'joe', 'operator': 'ecoin', 'zone': '.tech'}
# Match found for reyesaaron@mail.adlp.hu: {'name': 'reyesaaron', 'operator': 'mail', 'zone': '.adlp.hu'}
# Match found for ben.yang@ecoin.com: {'name': 'ben', 'last_name': 'yang', 'operator': 'ecoin', 'zone': '.com'}
# Match found for pettigrewgeorge@odul.me: {'name': 'pettigrewgeorge', 'operator': 'odul', 'zone': '.me'}
# Match found for miller.peter@mail.bocode.xyz: {'name': 'miller', 'last_name': 'peter', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for linde-carl@belgaximus.org: {'name': 'linde', 'last_name': 'carl', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for boyd_carl@napster.me: {'name': 'boyd', 'last_name': 'carl', 'operator': 'napster', 'zone': '.me'}
# Match found for yocum_mark@youhoo.com: {'name': 'yocum', 'last_name': 'mark', 'operator': 'youhoo', 'zone': '.com'}
# Match found for davidferro@mail.bocode.com: {'name': 'davidferro', 'operator': 'mail', 'zone': '.bocode.com'}
# Match found for george59@ecoin.gov: {'name': 'george59', 'operator': 'ecoin', 'zone': '.gov'}
# Match found for johnsen2201@imail.io: {'name': 'johnsen2201', 'operator': 'imail', 'zone': '.io'}
# Match found for thompson_adam@mail.bocode.me: {'name': 'thompson', 'last_name': 'adam', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for schutzlarry@email.apple: {'name': 'schutzlarry', 'operator': 'email', 'zone': '.apple'}
# Match found for quizoz.joe@napster.tech: {'name': 'quizoz', 'last_name': 'joe', 'operator': 'napster', 'zone': '.tech'}
# Match found for matthew8227@hotmoille.me: {'name': 'matthew8227', 'operator': 'hotmoille', 'zone': '.me'}
# Match found for alex@mail.bocode.net: {'name': 'alex', 'operator': 'mail', 'zone': '.bocode.net'}
# Match found for georgemoody@hotmoille.com: {'name': 'georgemoody', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for lawicki589@hotmoille.me: {'name': 'lawicki589', 'operator': 'hotmoille', 'zone': '.me'}
# Match found for doran7947@gaagle.tech: {'name': 'doran7947', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for baueraaron@mail.adlp.gov: {'name': 'baueraaron', 'operator': 'mail', 'zone': '.adlp.gov'}
# Match found for mark@email.io: {'name': 'mark', 'operator': 'email', 'zone': '.io'}
# Match found for waltermartin@ecoin.gov: {'name': 'waltermartin', 'operator': 'ecoin', 'zone': '.gov'}
# Match found for kaskel@mail.bocode.tech: {'name': 'kaskel', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for roberts_matthew@mail.bocode.hu: {'name': 'roberts', 'last_name': 'matthew', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for george@hotmoille.hu: {'name': 'george', 'operator': 'hotmoille', 'zone': '.hu'}
# Match found for ferry.victor@gaagle.com: {'name': 'ferry', 'last_name': 'victor', 'operator': 'gaagle', 'zone': '.com'}
# Match found for fred.weiss@odul.tech: {'name': 'fred', 'last_name': 'weiss', 'operator': 'odul', 'zone': '.tech'}
# Match found for jurgensonpeter@proton.tech: {'name': 'jurgensonpeter', 'operator': 'proton', 'zone': '.tech'}
# Match found for stevefietzer@ecoin.tech: {'name': 'stevefietzer', 'operator': 'ecoin', 'zone': '.tech'}
# Match found for sonderling_caswell@napster.tech: {'name': 'sonderling', 'last_name': 'caswell', 'operator': 'napster', 'zone': '.tech'}
# Match found for johnsen.walter@odul.net: {'name': 'johnsen', 'last_name': 'walter', 'operator': 'odul', 'zone': '.net'}
# Match found for mccormack@napster.xyz: {'name': 'mccormack', 'operator': 'napster', 'zone': '.xyz'}
# Match found for roberts.hank@proton.net: {'name': 'roberts', 'last_name': 'hank', 'operator': 'proton', 'zone': '.net'}
# Match found for valente@gaagle.xyz: {'name': 'valente', 'operator': 'gaagle', 'zone': '.xyz'}
# Match found for ory_walter@proton.hu: {'name': 'ory', 'last_name': 'walter', 'operator': 'proton', 'zone': '.hu'}
# Match found for tyirwin@proton.tech: {'name': 'tyirwin', 'operator': 'proton', 'zone': '.tech'}
# Match found for paulferry@hotmoille.com: {'name': 'paulferry', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for george@youhoo.gov: {'name': 'george', 'operator': 'youhoo', 'zone': '.gov'}
# Match found for frank.lulloff@mail.adlp.apple: {'name': 'frank', 'last_name': 'lulloff', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for ripka6596@mail.bocode.net: {'name': 'ripka6596', 'operator': 'mail', 'zone': '.bocode.net'}
# Match found for wagner_schuster@mail.adlp.me: {'name': 'wagner', 'last_name': 'schuster', 'operator': 'mail', 'zone': '.adlp.me'}
# Match found for mccormack.carl@imail.xyz: {'name': 'mccormack', 'last_name': 'carl', 'operator': 'imail', 'zone': '.xyz'}
# Match found for 851886792@youhoo.hu: {'name': '851886792', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for zeaser_aaron@belgaximus.apple: {'name': 'zeaser', 'last_name': 'aaron', 'operator': 'belgaximus', 'zone': '.apple'}
# Match found for adam@proton.net: {'name': 'adam', 'operator': 'proton', 'zone': '.net'}
# Match found for tisler.roger@hotmoille.tech: {'name': 'tisler', 'last_name': 'roger', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for ferro-dan@proton.io: {'name': 'ferro', 'last_name': 'dan', 'operator': 'proton', 'zone': '.io'}
# Match found for reardon-alex@gaagle.tech: {'name': 'reardon', 'last_name': 'alex', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for severson_george@proton.org: {'name': 'severson', 'last_name': 'george', 'operator': 'proton', 'zone': '.org'}
# Match found for otto.nuttle@proton.hu: {'name': 'otto', 'last_name': 'nuttle', 'operator': 'proton', 'zone': '.hu'}
# Match found for illingsworth@belgaximus.gov: {'name': 'illingsworth', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for danfletcher@mail.adlp.net: {'name': 'danfletcher', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for alex685@hotmoille.com: {'name': 'alex685', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for hancock_valente@hotmoille.net: {'name': 'hancock', 'last_name': 'valente', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for carl7884@mail.adlp.apple: {'name': 'carl7884', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for paul9581@email.tech: {'name': 'paul9581', 'operator': 'email', 'zone': '.tech'}
# Match found for sawyer_chambers@belgaximus.xyz: {'name': 'sawyer', 'last_name': 'chambers', 'operator': 'belgaximus', 'zone': '.xyz'}
# Match found for johnsen.tim@email.gov: {'name': 'johnsen', 'last_name': 'tim', 'operator': 'email', 'zone': '.gov'}
# Match found for aaron.roberts@imail.gov: {'name': 'aaron', 'last_name': 'roberts', 'operator': 'imail', 'zone': '.gov'}
# Match found for schiebel2392@hotmoille.xyz: {'name': 'schiebel2392', 'operator': 'hotmoille', 'zone': '.xyz'}
# Match found for mccormackedward@proton.com: {'name': 'mccormackedward', 'operator': 'proton', 'zone': '.com'}
# Match found for tapia1876@imail.tech: {'name': 'tapia1876', 'operator': 'imail', 'zone': '.tech'}
# Match found for quizoz9628@belgaximus.apple: {'name': 'quizoz9628', 'operator': 'belgaximus', 'zone': '.apple'}
# Match found for rogerstahl@odul.apple: {'name': 'rogerstahl', 'operator': 'odul', 'zone': '.apple'}
# Match found for schutz_johnsen@ecoin.tech: {'name': 'schutz', 'last_name': 'johnsen', 'operator': 'ecoin', 'zone': '.tech'}
# Match found for schutz-monte@hotmoille.net: {'name': 'schutz', 'last_name': 'monte', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for carlupson@napster.me: {'name': 'carlupson', 'operator': 'napster', 'zone': '.me'}
# Match found for larry349@odul.me: {'name': 'larry349', 'operator': 'odul', 'zone': '.me'}
# Match found for matthew.linde@youhoo.tech: {'name': 'matthew', 'last_name': 'linde', 'operator': 'youhoo', 'zone': '.tech'}
# Match found for mcginnis@imail.xyz: {'name': 'mcginnis', 'operator': 'imail', 'zone': '.xyz'}
# Match found for kalleg.monte@mail.adlp.com: {'name': 'kalleg', 'last_name': 'monte', 'operator': 'mail', 'zone': '.adlp.com'}
# Match found for nugent_jack@gaagle.hu: {'name': 'nugent', 'last_name': 'jack', 'operator': 'gaagle', 'zone': '.hu'}
# Match found for wagle_john@napster.gov: {'name': 'wagle', 'last_name': 'john', 'operator': 'napster', 'zone': '.gov'}
# Match found for chapmannathan@youhoo.org: {'name': 'chapmannathan', 'operator': 'youhoo', 'zone': '.org'}
# Match found for christensen-larry@hotmoille.net: {'name': 'christensen', 'last_name': 'larry', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for hal536@napster.net: {'name': 'hal536', 'operator': 'napster', 'zone': '.net'}
# Match found for 472510707@odul.io: {'name': '472510707', 'operator': 'odul', 'zone': '.io'}
# Match found for thomas.casal@hotmoille.com: {'name': 'thomas', 'last_name': 'casal', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for adamillingsworth@youhoo.xyz: {'name': 'adamillingsworth', 'operator': 'youhoo', 'zone': '.xyz'}
# Match found for weiss-adam@mail.adlp.tech: {'name': 'weiss', 'last_name': 'adam', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for peterstahl@gaagle.me: {'name': 'peterstahl', 'operator': 'gaagle', 'zone': '.me'}
# Match found for victortandy@youhoo.hu: {'name': 'victortandy', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for fredturco@mail.bocode.hu: {'name': 'fredturco', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for adam.sellon@email.tech: {'name': 'adam', 'last_name': 'sellon', 'operator': 'email', 'zone': '.tech'}
# Match found for vader-matthew@belgaximus.gov: {'name': 'vader', 'last_name': 'matthew', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for ike3831@proton.apple: {'name': 'ike3831', 'operator': 'proton', 'zone': '.apple'}
# Match found for timfletcher@imail.xyz: {'name': 'timfletcher', 'operator': 'imail', 'zone': '.xyz'}
# Match found for frank.schickowski@gaagle.io: {'name': 'frank', 'last_name': 'schickowski', 'operator': 'gaagle', 'zone': '.io'}
# Match found for 566486749@email.net: {'name': '566486749', 'operator': 'email', 'zone': '.net'}
# Match found for 675340599@proton.org: {'name': '675340599', 'operator': 'proton', 'zone': '.org'}
# Match found for davis_nathan@ecoin.com: {'name': 'davis', 'last_name': 'nathan', 'operator': 'ecoin', 'zone': '.com'}
# Match found for 253159777@gaagle.net: {'name': '253159777', 'operator': 'gaagle', 'zone': '.net'}
# Match found for edwardschutz@hotmoille.net: {'name': 'edwardschutz', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for sagar_carl@hotmoille.org: {'name': 'sagar', 'last_name': 'carl', 'operator': 'hotmoille', 'zone': '.org'}
# Match found for 331837931@napster.me: {'name': '331837931', 'operator': 'napster', 'zone': '.me'}
# Match found for aaronbongard@odul.xyz: {'name': 'aaronbongard', 'operator': 'odul', 'zone': '.xyz'}
# Match found for ty9516@belgaximus.net: {'name': 'ty9516', 'operator': 'belgaximus', 'zone': '.net'}
# Match found for fred@mail.adlp.apple: {'name': 'fred', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for schustersteve@proton.tech: {'name': 'schustersteve', 'operator': 'proton', 'zone': '.tech'}
# Match found for moody_schiebel@hotmoille.me: {'name': 'moody', 'last_name': 'schiebel', 'operator': 'hotmoille', 'zone': '.me'}
# Match found for soloman_ramachandran@gaagle.org: {'name': 'soloman', 'last_name': 'ramachandran', 'operator': 'gaagle', 'zone': '.org'}
# Match found for victor630@hotmoille.hu: {'name': 'victor630', 'operator': 'hotmoille', 'zone': '.hu'}
# Match found for yang_trebil@imail.me: {'name': 'yang', 'last_name': 'trebil', 'operator': 'imail', 'zone': '.me'}
# Match found for hoffman_zeller@imail.me: {'name': 'hoffman', 'last_name': 'zeller', 'operator': 'imail', 'zone': '.me'}
# Match found for ripka_thomas@email.tech: {'name': 'ripka', 'last_name': 'thomas', 'operator': 'email', 'zone': '.tech'}
# Match found for vader.hal@belgaximus.org: {'name': 'vader', 'last_name': 'hal', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for ottochambers@imail.io: {'name': 'ottochambers', 'operator': 'imail', 'zone': '.io'}
# Match found for tylulloff@email.gov: {'name': 'tylulloff', 'operator': 'email', 'zone': '.gov'}
# Match found for 263935905@youhoo.tech: {'name': '263935905', 'operator': 'youhoo', 'zone': '.tech'}
# Match found for carlvail@napster.me: {'name': 'carlvail', 'operator': 'napster', 'zone': '.me'}
# Match found for hanktisler@ecoin.com: {'name': 'hanktisler', 'operator': 'ecoin', 'zone': '.com'}
# Match found for uddin1510@email.org: {'name': 'uddin1510', 'operator': 'email', 'zone': '.org'}
# Match found for mccormack.carl@proton.net: {'name': 'mccormack', 'last_name': 'carl', 'operator': 'proton', 'zone': '.net'}
# Match found for vader@proton.me: {'name': 'vader', 'operator': 'proton', 'zone': '.me'}
# Match found for nelsonmark@imail.xyz: {'name': 'nelsonmark', 'operator': 'imail', 'zone': '.xyz'}
# No match for: adamvan zandt@belgaximus.hu
# Match found for ziegler-dan@proton.me: {'name': 'ziegler', 'last_name': 'dan', 'operator': 'proton', 'zone': '.me'}
# Match found for uflan@mail.adlp.gov: {'name': 'uflan', 'operator': 'mail', 'zone': '.adlp.gov'}
# Match found for sawyer-frank@ecoin.net: {'name': 'sawyer', 'last_name': 'frank', 'operator': 'ecoin', 'zone': '.net'}
# Match found for dan6858@mail.adlp.io: {'name': 'dan6858', 'operator': 'mail', 'zone': '.adlp.io'}
# Match found for stahl@odul.apple: {'name': 'stahl', 'operator': 'odul', 'zone': '.apple'}
# Match found for timirwin@hotmoille.me: {'name': 'timirwin', 'operator': 'hotmoille', 'zone': '.me'}
# Match found for davis9134@imail.tech: {'name': 'davis9134', 'operator': 'imail', 'zone': '.tech'}
# Match found for benuflan@mail.adlp.org: {'name': 'benuflan', 'operator': 'mail', 'zone': '.adlp.org'}
# Match found for davidziegler@imail.tech: {'name': 'davidziegler', 'operator': 'imail', 'zone': '.tech'}
# Match found for carl1959@youhoo.apple: {'name': 'carl1959', 'operator': 'youhoo', 'zone': '.apple'}
# Match found for alexkeller@gaagle.com: {'name': 'alexkeller', 'operator': 'gaagle', 'zone': '.com'}
# Match found for ostranderjoe@mail.bocode.tech: {'name': 'ostranderjoe', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for 469322116@hotmoille.tech: {'name': '469322116', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for monte7207@gaagle.hu: {'name': 'monte7207', 'operator': 'gaagle', 'zone': '.hu'}
# Match found for lawicki@mail.adlp.io: {'name': 'lawicki', 'operator': 'mail', 'zone': '.adlp.io'}
# Match found for fredtiernan@email.net: {'name': 'fredtiernan', 'operator': 'email', 'zone': '.net'}
# Match found for fietzer@gaagle.org: {'name': 'fietzer', 'operator': 'gaagle', 'zone': '.org'}
# Match found for benquinn@proton.com: {'name': 'benquinn', 'operator': 'proton', 'zone': '.com'}
# Match found for matthew8594@mail.adlp.xyz: {'name': 'matthew8594', 'operator': 'mail', 'zone': '.adlp.xyz'}
# Match found for hal.weiss@email.xyz: {'name': 'hal', 'last_name': 'weiss', 'operator': 'email', 'zone': '.xyz'}
# Match found for sweeney.otto@gaagle.apple: {'name': 'sweeney', 'last_name': 'otto', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for fletcher_monte@email.com: {'name': 'fletcher', 'last_name': 'monte', 'operator': 'email', 'zone': '.com'}
# Match found for adamkalleg@mail.bocode.hu: {'name': 'adamkalleg', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for woothomas@napster.tech: {'name': 'woothomas', 'operator': 'napster', 'zone': '.tech'}
# Match found for thomasdavidson@mail.bocode.io: {'name': 'thomasdavidson', 'operator': 'mail', 'zone': '.bocode.io'}
# Match found for moore3490@mail.adlp.me: {'name': 'moore3490', 'operator': 'mail', 'zone': '.adlp.me'}
# Match found for walter@napster.io: {'name': 'walter', 'operator': 'napster', 'zone': '.io'}
# Match found for ventotla.alex@mail.adlp.tech: {'name': 'ventotla', 'last_name': 'alex', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for dinkins@proton.gov: {'name': 'dinkins', 'operator': 'proton', 'zone': '.gov'}
# Match found for 950099319@imail.net: {'name': '950099319', 'operator': 'imail', 'zone': '.net'}
# Match found for roger.myers@gaagle.io: {'name': 'roger', 'last_name': 'myers', 'operator': 'gaagle', 'zone': '.io'}
# Match found for tim.trusela@hotmoille.gov: {'name': 'tim', 'last_name': 'trusela', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for sawyer.adam@belgaximus.org: {'name': 'sawyer', 'last_name': 'adam', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for ben.jagtap@napster.tech: {'name': 'ben', 'last_name': 'jagtap', 'operator': 'napster', 'zone': '.tech'}
# Match found for carlmills@ecoin.me: {'name': 'carlmills', 'operator': 'ecoin', 'zone': '.me'}
# Match found for markboyd@belgaximus.apple: {'name': 'markboyd', 'operator': 'belgaximus', 'zone': '.apple'}
# Match found for johnyocum@mail.adlp.apple: {'name': 'johnyocum', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for 887934540@email.net: {'name': '887934540', 'operator': 'email', 'zone': '.net'}
# Match found for ortizjack@gaagle.gov: {'name': 'ortizjack', 'operator': 'gaagle', 'zone': '.gov'}
# Match found for tiernan4456@mail.adlp.xyz: {'name': 'tiernan4456', 'operator': 'mail', 'zone': '.adlp.xyz'}
# Match found for roberts_myers@email.tech: {'name': 'roberts', 'last_name': 'myers', 'operator': 'email', 'zone': '.tech'}
# Match found for soloman8370@odul.gov: {'name': 'soloman8370', 'operator': 'odul', 'zone': '.gov'}
# Match found for alex3716@ecoin.me: {'name': 'alex3716', 'operator': 'ecoin', 'zone': '.me'}
# Match found for tim@proton.me: {'name': 'tim', 'operator': 'proton', 'zone': '.me'}
# Match found for thompson85@proton.hu: {'name': 'thompson85', 'operator': 'proton', 'zone': '.hu'}
# Match found for reyes.jack@email.hu: {'name': 'reyes', 'last_name': 'jack', 'operator': 'email', 'zone': '.hu'}
# Match found for resnick@mail.bocode.hu: {'name': 'resnick', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for dinkinsroger@youhoo.apple: {'name': 'dinkinsroger', 'operator': 'youhoo', 'zone': '.apple'}
# Match found for mills9634@odul.xyz: {'name': 'mills9634', 'operator': 'odul', 'zone': '.xyz'}
# Match found for 821464747@odul.gov: {'name': '821464747', 'operator': 'odul', 'zone': '.gov'}
# Match found for valente_hydinger@hotmoille.tech: {'name': 'valente', 'last_name': 'hydinger', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for schiebel1467@proton.io: {'name': 'schiebel1467', 'operator': 'proton', 'zone': '.io'}
# Match found for larryschiebel@ecoin.net: {'name': 'larryschiebel', 'operator': 'ecoin', 'zone': '.net'}
# Match found for adamostrander@mail.adlp.gov: {'name': 'adamostrander', 'operator': 'mail', 'zone': '.adlp.gov'}
# Match found for jagtap.fred@proton.gov: {'name': 'jagtap', 'last_name': 'fred', 'operator': 'proton', 'zone': '.gov'}
# Match found for edward.haworth@imail.com: {'name': 'edward', 'last_name': 'haworth', 'operator': 'imail', 'zone': '.com'}
# Match found for matthewcataldi@youhoo.net: {'name': 'matthewcataldi', 'operator': 'youhoo', 'zone': '.net'}
# Match found for resnick_moore@mail.adlp.tech: {'name': 'resnick', 'last_name': 'moore', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for zeller@email.org: {'name': 'zeller', 'operator': 'email', 'zone': '.org'}
# Match found for trebil-george@youhoo.apple: {'name': 'trebil', 'last_name': 'george', 'operator': 'youhoo', 'zone': '.apple'}
# Match found for duffman@email.net: {'name': 'duffman', 'operator': 'email', 'zone': '.net'}
# Match found for ottoortiz@youhoo.xyz: {'name': 'ottoortiz', 'operator': 'youhoo', 'zone': '.xyz'}
# Match found for david.rice@mail.bocode.org: {'name': 'david', 'last_name': 'rice', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for delorenzo@ecoin.me: {'name': 'delorenzo', 'operator': 'ecoin', 'zone': '.me'}
# Match found for miller_keller@email.org: {'name': 'miller', 'last_name': 'keller', 'operator': 'email', 'zone': '.org'}
# Match found for illingsworth@youhoo.gov: {'name': 'illingsworth', 'operator': 'youhoo', 'zone': '.gov'}
# Match found for nelson@odul.tech: {'name': 'nelson', 'operator': 'odul', 'zone': '.tech'}
# Match found for rogers_john@gaagle.tech: {'name': 'rogers', 'last_name': 'john', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for fredwagner@mail.adlp.org: {'name': 'fredwagner', 'operator': 'mail', 'zone': '.adlp.org'}
# Match found for tyresnick@imail.io: {'name': 'tyresnick', 'operator': 'imail', 'zone': '.io'}
# Match found for hal.yang@napster.xyz: {'name': 'hal', 'last_name': 'yang', 'operator': 'napster', 'zone': '.xyz'}
# Match found for tiernan6950@belgaximus.tech: {'name': 'tiernan6950', 'operator': 'belgaximus', 'zone': '.tech'}
# Match found for schuster-john@email.tech: {'name': 'schuster', 'last_name': 'john', 'operator': 'email', 'zone': '.tech'}
# Match found for mills@belgaximus.xyz: {'name': 'mills', 'operator': 'belgaximus', 'zone': '.xyz'}
# Match found for casal.hank@proton.xyz: {'name': 'casal', 'last_name': 'hank', 'operator': 'proton', 'zone': '.xyz'}
# No match for: roger.van zandt@gaagle.org
# Match found for stevevader@mail.bocode.me: {'name': 'stevevader', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for hankupson@odul.xyz: {'name': 'hankupson', 'operator': 'odul', 'zone': '.xyz'}
# Match found for 184536366@mail.adlp.me: {'name': '184536366', 'operator': 'mail', 'zone': '.adlp.me'}
# Match found for irwin_yang@gaagle.gov: {'name': 'irwin', 'last_name': 'yang', 'operator': 'gaagle', 'zone': '.gov'}
# Match found for napier.aaron@email.org: {'name': 'napier', 'last_name': 'aaron', 'operator': 'email', 'zone': '.org'}
# Match found for edward.schickowski@youhoo.xyz: {'name': 'edward', 'last_name': 'schickowski', 'operator': 'youhoo', 'zone': '.xyz'}
# Match found for fletcher-alex@imail.com: {'name': 'fletcher', 'last_name': 'alex', 'operator': 'imail', 'zone': '.com'}
# Match found for chambers-monte@mail.adlp.gov: {'name': 'chambers', 'last_name': 'monte', 'operator': 'mail', 'zone': '.adlp.gov'}
# Match found for rogers_lawicki@gaagle.apple: {'name': 'rogers', 'last_name': 'lawicki', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for tapia_upson@ecoin.me: {'name': 'tapia', 'last_name': 'upson', 'operator': 'ecoin', 'zone': '.me'}
# Match found for uddin_yocum@gaagle.hu: {'name': 'uddin', 'last_name': 'yocum', 'operator': 'gaagle', 'zone': '.hu'}
# Match found for bongardroger@napster.net: {'name': 'bongardroger', 'operator': 'napster', 'zone': '.net'}
# Match found for victor@youhoo.gov: {'name': 'victor', 'operator': 'youhoo', 'zone': '.gov'}
# Match found for ty.schwager@napster.io: {'name': 'ty', 'last_name': 'schwager', 'operator': 'napster', 'zone': '.io'}
# Match found for paultiernan@youhoo.xyz: {'name': 'paultiernan', 'operator': 'youhoo', 'zone': '.xyz'}
# Match found for roger836@gaagle.tech: {'name': 'roger836', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for pettigrew.victor@email.io: {'name': 'pettigrew', 'last_name': 'victor', 'operator': 'email', 'zone': '.io'}
# Match found for steve.ingram@mail.bocode.me: {'name': 'steve', 'last_name': 'ingram', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for johnsen4863@gaagle.apple: {'name': 'johnsen4863', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for soloman-roger@ecoin.apple: {'name': 'soloman', 'last_name': 'roger', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for 34658710@mail.bocode.xyz: {'name': '34658710', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for cannon-joe@mail.bocode.io: {'name': 'cannon', 'last_name': 'joe', 'operator': 'mail', 'zone': '.bocode.io'}
# Match found for 284857146@mail.adlp.net: {'name': '284857146', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for 890280316@ecoin.me: {'name': '890280316', 'operator': 'ecoin', 'zone': '.me'}
# Match found for kalleg-joe@belgaximus.com: {'name': 'kalleg', 'last_name': 'joe', 'operator': 'belgaximus', 'zone': '.com'}
# Match found for weinstein.roger@imail.io: {'name': 'weinstein', 'last_name': 'roger', 'operator': 'imail', 'zone': '.io'}
# Match found for alexschmitt@odul.org: {'name': 'alexschmitt', 'operator': 'odul', 'zone': '.org'}
# Match found for dan.uddin@ecoin.apple: {'name': 'dan', 'last_name': 'uddin', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for steve.stahl@hotmoille.me: {'name': 'steve', 'last_name': 'stahl', 'operator': 'hotmoille', 'zone': '.me'}
# Match found for matthewfrick@hotmoille.com: {'name': 'matthewfrick', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for 237336989@email.io: {'name': '237336989', 'operator': 'email', 'zone': '.io'}
# Match found for larry6016@youhoo.org: {'name': 'larry6016', 'operator': 'youhoo', 'zone': '.org'}
# Match found for otto5489@gaagle.tech: {'name': 'otto5489', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for bongard_ty@ecoin.xyz: {'name': 'bongard', 'last_name': 'ty', 'operator': 'ecoin', 'zone': '.xyz'}
# Match found for 169102677@gaagle.me: {'name': '169102677', 'operator': 'gaagle', 'zone': '.me'}
# Match found for upson.hal@gaagle.io: {'name': 'upson', 'last_name': 'hal', 'operator': 'gaagle', 'zone': '.io'}
# Match found for hal@hotmoille.gov: {'name': 'hal', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for lepage-aaron@hotmoille.apple: {'name': 'lepage', 'last_name': 'aaron', 'operator': 'hotmoille', 'zone': '.apple'}
# Match found for sonderling_mark@belgaximus.me: {'name': 'sonderling', 'last_name': 'mark', 'operator': 'belgaximus', 'zone': '.me'}
# Match found for 430581778@hotmoille.com: {'name': '430581778', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for walterkassing@napster.tech: {'name': 'walterkassing', 'operator': 'napster', 'zone': '.tech'}
# Match found for victorceledon@ecoin.xyz: {'name': 'victorceledon', 'operator': 'ecoin', 'zone': '.xyz'}
# Match found for hesch-john@odul.io: {'name': 'hesch', 'last_name': 'john', 'operator': 'odul', 'zone': '.io'}
# Match found for kassing@hotmoille.apple: {'name': 'kassing', 'operator': 'hotmoille', 'zone': '.apple'}
# Match found for duffman6005@youhoo.hu: {'name': 'duffman6005', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for frank.ventotla@belgaximus.io: {'name': 'frank', 'last_name': 'ventotla', 'operator': 'belgaximus', 'zone': '.io'}
# Match found for uddinotto@youhoo.org: {'name': 'uddinotto', 'operator': 'youhoo', 'zone': '.org'}
# Match found for 703979481@ecoin.apple: {'name': '703979481', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for paul.nugent@ecoin.apple: {'name': 'paul', 'last_name': 'nugent', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for nugent@proton.org: {'name': 'nugent', 'operator': 'proton', 'zone': '.org'}
# Match found for alex@odul.tech: {'name': 'alex', 'operator': 'odul', 'zone': '.tech'}
# Match found for aaronsweeney@ecoin.apple: {'name': 'aaronsweeney', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for knutson_celedon@hotmoille.xyz: {'name': 'knutson', 'last_name': 'celedon', 'operator': 'hotmoille', 'zone': '.xyz'}
# Match found for tydoran@belgaximus.org: {'name': 'tydoran', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for millerhal@hotmoille.org: {'name': 'millerhal', 'operator': 'hotmoille', 'zone': '.org'}
# Match found for adamnuttle@youhoo.hu: {'name': 'adamnuttle', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for ashwoon8609@youhoo.tech: {'name': 'ashwoon8609', 'operator': 'youhoo', 'zone': '.tech'}
# Match found for victormiller@mail.bocode.org: {'name': 'victormiller', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for mcginnis_reardon@youhoo.org: {'name': 'mcginnis', 'last_name': 'reardon', 'operator': 'youhoo', 'zone': '.org'}
# Match found for ramachandran.mark@proton.com: {'name': 'ramachandran', 'last_name': 'mark', 'operator': 'proton', 'zone': '.com'}
# Match found for monteshaffer@proton.tech: {'name': 'monteshaffer', 'operator': 'proton', 'zone': '.tech'}
# Match found for monte@proton.gov: {'name': 'monte', 'operator': 'proton', 'zone': '.gov'}
# Match found for pettigrew9750@proton.com: {'name': 'pettigrew9750', 'operator': 'proton', 'zone': '.com'}
# Match found for yocum_dan@napster.xyz: {'name': 'yocum', 'last_name': 'dan', 'operator': 'napster', 'zone': '.xyz'}
# Match found for yocum-victor@imail.xyz: {'name': 'yocum', 'last_name': 'victor', 'operator': 'imail', 'zone': '.xyz'}
# Match found for darnell8483@email.xyz: {'name': 'darnell8483', 'operator': 'email', 'zone': '.xyz'}
# Match found for zeller-matthew@ecoin.apple: {'name': 'zeller', 'last_name': 'matthew', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for pettigrewlarry@imail.tech: {'name': 'pettigrewlarry', 'operator': 'imail', 'zone': '.tech'}
# Match found for yocum8146@mail.bocode.me: {'name': 'yocum8146', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for ben5039@hotmoille.tech: {'name': 'ben5039', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for mcginnis.dan@gaagle.tech: {'name': 'mcginnis', 'last_name': 'dan', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for roger.vogal@email.xyz: {'name': 'roger', 'last_name': 'vogal', 'operator': 'email', 'zone': '.xyz'}
# Match found for adamtisler@gaagle.xyz: {'name': 'adamtisler', 'operator': 'gaagle', 'zone': '.xyz'}
# Match found for matthew3420@hotmoille.tech: {'name': 'matthew3420', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for john8770@napster.hu: {'name': 'john8770', 'operator': 'napster', 'zone': '.hu'}
# Match found for hesch_zeller@email.apple: {'name': 'hesch', 'last_name': 'zeller', 'operator': 'email', 'zone': '.apple'}
# Match found for christensen_ben@proton.com: {'name': 'christensen', 'last_name': 'ben', 'operator': 'proton', 'zone': '.com'}
# Match found for walter.soulis@email.com: {'name': 'walter', 'last_name': 'soulis', 'operator': 'email', 'zone': '.com'}
# Match found for ben8671@proton.tech: {'name': 'ben8671', 'operator': 'proton', 'zone': '.tech'}
# Match found for frankjagtap@napster.com: {'name': 'frankjagtap', 'operator': 'napster', 'zone': '.com'}
# Match found for peternuttle@napster.gov: {'name': 'peternuttle', 'operator': 'napster', 'zone': '.gov'}
# Match found for victor8847@ecoin.io: {'name': 'victor8847', 'operator': 'ecoin', 'zone': '.io'}
# Match found for ferry.paul@imail.org: {'name': 'ferry', 'last_name': 'paul', 'operator': 'imail', 'zone': '.org'}
# Match found for 690377034@gaagle.apple: {'name': '690377034', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for lepageroger@proton.gov: {'name': 'lepageroger', 'operator': 'proton', 'zone': '.gov'}
# Match found for john.zeaser@imail.gov: {'name': 'john', 'last_name': 'zeaser', 'operator': 'imail', 'zone': '.gov'}
# Match found for valente-jack@gaagle.me: {'name': 'valente', 'last_name': 'jack', 'operator': 'gaagle', 'zone': '.me'}
# Match found for 4709006@napster.tech: {'name': '4709006', 'operator': 'napster', 'zone': '.tech'}
# Match found for deitz-monte@odul.gov: {'name': 'deitz', 'last_name': 'monte', 'operator': 'odul', 'zone': '.gov'}
# Match found for fietzer-frank@hotmoille.tech: {'name': 'fietzer', 'last_name': 'frank', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for kaskel5284@belgaximus.org: {'name': 'kaskel5284', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for davidson-monte@mail.bocode.xyz: {'name': 'davidson', 'last_name': 'monte', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for cataldi_ingram@mail.bocode.tech: {'name': 'cataldi', 'last_name': 'ingram', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for hanktiernan@youhoo.io: {'name': 'hanktiernan', 'operator': 'youhoo', 'zone': '.io'}
# Match found for ripka2474@hotmoille.tech: {'name': 'ripka2474', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for cataldi_matthew@odul.me: {'name': 'cataldi', 'last_name': 'matthew', 'operator': 'odul', 'zone': '.me'}
# Match found for lewis_lulloff@mail.adlp.org: {'name': 'lewis', 'last_name': 'lulloff', 'operator': 'mail', 'zone': '.adlp.org'}
# Match found for matthewmccord@mail.bocode.me: {'name': 'matthewmccord', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for turco8476@mail.adlp.apple: {'name': 'turco8476', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for steve6967@odul.hu: {'name': 'steve6967', 'operator': 'odul', 'zone': '.hu'}
# Match found for ortiz-larry@napster.org: {'name': 'ortiz', 'last_name': 'larry', 'operator': 'napster', 'zone': '.org'}
# Match found for irwincarl@belgaximus.gov: {'name': 'irwincarl', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for wakefieldjoe@ecoin.org: {'name': 'wakefieldjoe', 'operator': 'ecoin', 'zone': '.org'}
# Match found for nathansagar@email.apple: {'name': 'nathansagar', 'operator': 'email', 'zone': '.apple'}
# Match found for hydinger_larry@odul.xyz: {'name': 'hydinger', 'last_name': 'larry', 'operator': 'odul', 'zone': '.xyz'}
# Match found for frank.yates@proton.gov: {'name': 'frank', 'last_name': 'yates', 'operator': 'proton', 'zone': '.gov'}
# Match found for fred@mail.adlp.apple: {'name': 'fred', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for schuster5868@youhoo.tech: {'name': 'schuster5868', 'operator': 'youhoo', 'zone': '.tech'}
# Match found for rogerschwager@imail.tech: {'name': 'rogerschwager', 'operator': 'imail', 'zone': '.tech'}
# Match found for 163622426@imail.com: {'name': '163622426', 'operator': 'imail', 'zone': '.com'}
# Match found for baxstercarl@proton.net: {'name': 'baxstercarl', 'operator': 'proton', 'zone': '.net'}
# Match found for yang-hal@mail.adlp.net: {'name': 'yang', 'last_name': 'hal', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for aikin@napster.gov: {'name': 'aikin', 'operator': 'napster', 'zone': '.gov'}
# Match found for ortiz-david@mail.adlp.io: {'name': 'ortiz', 'last_name': 'david', 'operator': 'mail', 'zone': '.adlp.io'}
# Match found for tisler_reyes@imail.io: {'name': 'tisler', 'last_name': 'reyes', 'operator': 'imail', 'zone': '.io'}
# Match found for stahl-thomas@mail.bocode.org: {'name': 'stahl', 'last_name': 'thomas', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for aaron.trusela@mail.adlp.gov: {'name': 'aaron', 'last_name': 'trusela', 'operator': 'mail', 'zone': '.adlp.gov'}
# Match found for 573168868@mail.adlp.tech: {'name': '573168868', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for monte1021@hotmoille.gov: {'name': 'monte1021', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for petermccord@mail.bocode.xyz: {'name': 'petermccord', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for quizoz@proton.apple: {'name': 'quizoz', 'operator': 'proton', 'zone': '.apple'}
# Match found for vail_soukup@proton.apple: {'name': 'vail', 'last_name': 'soukup', 'operator': 'proton', 'zone': '.apple'}
# Match found for thomassonderling@napster.com: {'name': 'thomassonderling', 'operator': 'napster', 'zone': '.com'}
# Match found for frankaikin@odul.io: {'name': 'frankaikin', 'operator': 'odul', 'zone': '.io'}
# Match found for aaronillingsworth@hotmoille.com: {'name': 'aaronillingsworth', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for 859491337@youhoo.hu: {'name': '859491337', 'operator': 'youhoo', 'zone': '.hu'}
# Match found for paul.eastman@napster.io: {'name': 'paul', 'last_name': 'eastman', 'operator': 'napster', 'zone': '.io'}
# Match found for waltertisler@belgaximus.apple: {'name': 'waltertisler', 'operator': 'belgaximus', 'zone': '.apple'}
# Match found for ferro_caswell@hotmoille.com: {'name': 'ferro', 'last_name': 'caswell', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for george@gaagle.hu: {'name': 'george', 'operator': 'gaagle', 'zone': '.hu'}
# Match found for timorwig@email.io: {'name': 'timorwig', 'operator': 'email', 'zone': '.io'}
# Match found for jones@napster.net: {'name': 'jones', 'operator': 'napster', 'zone': '.net'}
# Match found for hoffman.roger@youhoo.xyz: {'name': 'hoffman', 'last_name': 'roger', 'operator': 'youhoo', 'zone': '.xyz'}
# Match found for ashwoon@mail.bocode.tech: {'name': 'ashwoon', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for matthew.trusela@imail.io: {'name': 'matthew', 'last_name': 'trusela', 'operator': 'imail', 'zone': '.io'}
# Match found for larry2207@imail.apple: {'name': 'larry2207', 'operator': 'imail', 'zone': '.apple'}
# Match found for rice_sonderling@gaagle.hu: {'name': 'rice', 'last_name': 'sonderling', 'operator': 'gaagle', 'zone': '.hu'}
# Match found for nuttleben@proton.net: {'name': 'nuttleben', 'operator': 'proton', 'zone': '.net'}
# Match found for dewalt_martin@belgaximus.io: {'name': 'dewalt', 'last_name': 'martin', 'operator': 'belgaximus', 'zone': '.io'}
# Match found for ikekassing@gaagle.com: {'name': 'ikekassing', 'operator': 'gaagle', 'zone': '.com'}
# Match found for 240044289@odul.tech: {'name': '240044289', 'operator': 'odul', 'zone': '.tech'}
# Match found for otto@napster.hu: {'name': 'otto', 'operator': 'napster', 'zone': '.hu'}
# Match found for ferro.edward@imail.xyz: {'name': 'ferro', 'last_name': 'edward', 'operator': 'imail', 'zone': '.xyz'}
# Match found for hankanderson@imail.net: {'name': 'hankanderson', 'operator': 'imail', 'zone': '.net'}
# Match found for deitz-roger@odul.net: {'name': 'deitz', 'last_name': 'roger', 'operator': 'odul', 'zone': '.net'}
# Match found for turco_ike@mail.adlp.xyz: {'name': 'turco', 'last_name': 'ike', 'operator': 'mail', 'zone': '.adlp.xyz'}
# Match found for dan.deitz@belgaximus.gov: {'name': 'dan', 'last_name': 'deitz', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for orwig_sweeney@proton.me: {'name': 'orwig', 'last_name': 'sweeney', 'operator': 'proton', 'zone': '.me'}
# Match found for bencaswell@youhoo.apple: {'name': 'bencaswell', 'operator': 'youhoo', 'zone': '.apple'}
# Match found for chambers.victor@email.net: {'name': 'chambers', 'last_name': 'victor', 'operator': 'email', 'zone': '.net'}
# Match found for sweeney_david@mail.bocode.hu: {'name': 'sweeney', 'last_name': 'david', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for 579081959@ecoin.hu: {'name': '579081959', 'operator': 'ecoin', 'zone': '.hu'}
# Match found for moore.fred@imail.com: {'name': 'moore', 'last_name': 'fred', 'operator': 'imail', 'zone': '.com'}
# Match found for thomas@gaagle.me: {'name': 'thomas', 'operator': 'gaagle', 'zone': '.me'}
# Match found for darnell-otto@imail.com: {'name': 'darnell', 'last_name': 'otto', 'operator': 'imail', 'zone': '.com'}
# Match found for orwig@imail.tech: {'name': 'orwig', 'operator': 'imail', 'zone': '.tech'}
# Match found for haworth-john@imail.org: {'name': 'haworth', 'last_name': 'john', 'operator': 'imail', 'zone': '.org'}
# Match found for nathankalleg@mail.bocode.xyz: {'name': 'nathankalleg', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for hal@imail.me: {'name': 'hal', 'operator': 'imail', 'zone': '.me'}
# Match found for yocum@mail.bocode.me: {'name': 'yocum', 'operator': 'mail', 'zone': '.bocode.me'}
# Match found for robertsalex@mail.adlp.gov: {'name': 'robertsalex', 'operator': 'mail', 'zone': '.adlp.gov'}
# Match found for alex9835@email.org: {'name': 'alex9835', 'operator': 'email', 'zone': '.org'}
# Match found for roberts-hank@hotmoille.hu: {'name': 'roberts', 'last_name': 'hank', 'operator': 'hotmoille', 'zone': '.hu'}
# Match found for nathanripka@belgaximus.com: {'name': 'nathanripka', 'operator': 'belgaximus', 'zone': '.com'}
# Match found for sonderling@napster.xyz: {'name': 'sonderling', 'operator': 'napster', 'zone': '.xyz'}
# Match found for matthew.duffman@gaagle.net: {'name': 'matthew', 'last_name': 'duffman', 'operator': 'gaagle', 'zone': '.net'}
# Match found for monte2098@odul.io: {'name': 'monte2098', 'operator': 'odul', 'zone': '.io'}
# Match found for victor.tiernan@email.hu: {'name': 'victor', 'last_name': 'tiernan', 'operator': 'email', 'zone': '.hu'}
# Match found for cataldi_john@mail.bocode.org: {'name': 'cataldi', 'last_name': 'john', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for 822140569@proton.net: {'name': '822140569', 'operator': 'proton', 'zone': '.net'}
# Match found for joe@hotmoille.com: {'name': 'joe', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for matthew@gaagle.tech: {'name': 'matthew', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for walter@napster.net: {'name': 'walter', 'operator': 'napster', 'zone': '.net'}
# Match found for baxster_zeaser@mail.bocode.hu: {'name': 'baxster', 'last_name': 'zeaser', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for schickowski-hal@proton.apple: {'name': 'schickowski', 'last_name': 'hal', 'operator': 'proton', 'zone': '.apple'}
# Match found for moody-alex@odul.org: {'name': 'moody', 'last_name': 'alex', 'operator': 'odul', 'zone': '.org'}
# Match found for yocum_ventotla@email.tech: {'name': 'yocum', 'last_name': 'ventotla', 'operator': 'email', 'zone': '.tech'}
# Match found for vader_sweeney@ecoin.hu: {'name': 'vader', 'last_name': 'sweeney', 'operator': 'ecoin', 'zone': '.hu'}
# Match found for schutz@mail.adlp.hu: {'name': 'schutz', 'operator': 'mail', 'zone': '.adlp.hu'}
# Match found for orwig_mills@youhoo.me: {'name': 'orwig', 'last_name': 'mills', 'operator': 'youhoo', 'zone': '.me'}
# Match found for roger7781@odul.io: {'name': 'roger7781', 'operator': 'odul', 'zone': '.io'}
# Match found for dugan_thomas@odul.tech: {'name': 'dugan', 'last_name': 'thomas', 'operator': 'odul', 'zone': '.tech'}
# Match found for lulloff@mail.adlp.net: {'name': 'lulloff', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for vader@gaagle.apple: {'name': 'vader', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for otto@gaagle.xyz: {'name': 'otto', 'operator': 'gaagle', 'zone': '.xyz'}
# Match found for sawyer_johnson@hotmoille.apple: {'name': 'sawyer', 'last_name': 'johnson', 'operator': 'hotmoille', 'zone': '.apple'}
# Match found for george@hotmoille.net: {'name': 'george', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for anderson.john@hotmoille.gov: {'name': 'anderson', 'last_name': 'john', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for hydinger_aaron@ecoin.com: {'name': 'hydinger', 'last_name': 'aaron', 'operator': 'ecoin', 'zone': '.com'}
# Match found for monte@hotmoille.com: {'name': 'monte', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for severson_aaron@proton.io: {'name': 'severson', 'last_name': 'aaron', 'operator': 'proton', 'zone': '.io'}
# Match found for jack.fletcher@napster.com: {'name': 'jack', 'last_name': 'fletcher', 'operator': 'napster', 'zone': '.com'}
# Match found for jurgensonpaul@ecoin.io: {'name': 'jurgensonpaul', 'operator': 'ecoin', 'zone': '.io'}
# Match found for 438861443@ecoin.gov: {'name': '438861443', 'operator': 'ecoin', 'zone': '.gov'}
# Match found for aaron@proton.com: {'name': 'aaron', 'operator': 'proton', 'zone': '.com'}
# Match found for fletcher_thompson@mail.adlp.com: {'name': 'fletcher', 'last_name': 'thompson', 'operator': 'mail', 'zone': '.adlp.com'}
# Match found for weiss2334@mail.bocode.net: {'name': 'weiss2334', 'operator': 'mail', 'zone': '.bocode.net'}
# Match found for eastman-ty@belgaximus.me: {'name': 'eastman', 'last_name': 'ty', 'operator': 'belgaximus', 'zone': '.me'}
# Match found for doran@email.org: {'name': 'doran', 'operator': 'email', 'zone': '.org'}
# Match found for sweeney_nathan@proton.xyz: {'name': 'sweeney', 'last_name': 'nathan', 'operator': 'proton', 'zone': '.xyz'}
# Match found for vogal9413@mail.bocode.tech: {'name': 'vogal9413', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for celedon_bauer@gaagle.net: {'name': 'celedon', 'last_name': 'bauer', 'operator': 'gaagle', 'zone': '.net'}
# Match found for vader-victor@mail.adlp.tech: {'name': 'vader', 'last_name': 'victor', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for 873166067@mail.bocode.net: {'name': '873166067', 'operator': 'mail', 'zone': '.bocode.net'}
# ...
# Match found for ory_nugent@email.xyz: {'name': 'ory', 'last_name': 'nugent', 'operator': 'email', 'zone': '.xyz'}
# Match found for solomangeorge@hotmoille.apple: {'name': 'solomangeorge', 'operator': 'hotmoille', 'zone': '.apple'}
# Match found for bateman_weinstein@belgaximus.gov: {'name': 'bateman', 'last_name': 'weinstein', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for zeaser@ecoin.gov: {'name': 'zeaser', 'operator': 'ecoin', 'zone': '.gov'}
# Match found for ulrichty@odul.hu: {'name': 'ulrichty', 'operator': 'odul', 'zone': '.hu'}
# Match found for irwin-paul@mail.bocode.xyz: {'name': 'irwin', 'last_name': 'paul', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for alexmcginnis@belgaximus.org: {'name': 'alexmcginnis', 'operator': 'belgaximus', 'zone': '.org'}
# Match found for cataldi.tim@mail.adlp.tech: {'name': 'cataldi', 'last_name': 'tim', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for halrice@hotmoille.hu: {'name': 'halrice', 'operator': 'hotmoille', 'zone': '.hu'}
# Match found for nelson.steve@imail.hu: {'name': 'nelson', 'last_name': 'steve', 'operator': 'imail', 'zone': '.hu'}
# Match found for vail_chapman@youhoo.net: {'name': 'vail', 'last_name': 'chapman', 'operator': 'youhoo', 'zone': '.net'}
# Match found for schiebelthomas@ecoin.hu: {'name': 'schiebelthomas', 'operator': 'ecoin', 'zone': '.hu'}
# Match found for ike.hancock@imail.apple: {'name': 'ike', 'last_name': 'hancock', 'operator': 'imail', 'zone': '.apple'}
# Match found for roger@belgaximus.hu: {'name': 'roger', 'operator': 'belgaximus', 'zone': '.hu'}
# Match found for nugent_fletcher@ecoin.hu: {'name': 'nugent', 'last_name': 'fletcher', 'operator': 'ecoin', 'zone': '.hu'}
# Match found for maki8692@imail.gov: {'name': 'maki8692', 'operator': 'imail', 'zone': '.gov'}
# Match found for adam@email.tech: {'name': 'adam', 'operator': 'email', 'zone': '.tech'}
# Match found for roger.maki@mail.bocode.apple: {'name': 'roger', 'last_name': 'maki', 'operator': 'mail', 'zone': '.bocode.apple'}
# Match found for sellon-david@ecoin.com: {'name': 'sellon', 'last_name': 'david', 'operator': 'ecoin', 'zone': '.com'}
# Match found for adam@hotmoille.io: {'name': 'adam', 'operator': 'hotmoille', 'zone': '.io'}
# Match found for thomasyates@odul.com: {'name': 'thomasyates', 'operator': 'odul', 'zone': '.com'}
# Match found for celedon_walter@napster.hu: {'name': 'celedon', 'last_name': 'walter', 'operator': 'napster', 'zone': '.hu'}
# Match found for kassing4495@proton.io: {'name': 'kassing4495', 'operator': 'proton', 'zone': '.io'}
# Match found for boyd_george@odul.io: {'name': 'boyd', 'last_name': 'george', 'operator': 'odul', 'zone': '.io'}
# Match found for bowers_ebner@email.xyz: {'name': 'bowers', 'last_name': 'ebner', 'operator': 'email', 'zone': '.xyz'}
# Match found for jack9352@odul.tech: {'name': 'jack9352', 'operator': 'odul', 'zone': '.tech'}
# Match found for lewisdan@youhoo.net: {'name': 'lewisdan', 'operator': 'youhoo', 'zone': '.net'}
# Match found for schmitt-roger@napster.tech: {'name': 'schmitt', 'last_name': 'roger', 'operator': 'napster', 'zone': '.tech'}
# Match found for mccormackmark@hotmoille.net: {'name': 'mccormackmark', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for timbauer@odul.org: {'name': 'timbauer', 'operator': 'odul', 'zone': '.org'}
# Match found for roger349@mail.adlp.net: {'name': 'roger349', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for reamer_rogers@proton.hu: {'name': 'reamer', 'last_name': 'rogers', 'operator': 'proton', 'zone': '.hu'}
# Match found for soulisfred@belgaximus.gov: {'name': 'soulisfred', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for vader.tim@hotmoille.xyz: {'name': 'vader', 'last_name': 'tim', 'operator': 'hotmoille', 'zone': '.xyz'}
# Match found for ory.hal@mail.bocode.apple: {'name': 'ory', 'last_name': 'hal', 'operator': 'mail', 'zone': '.bocode.apple'}
# Match found for wagnerthomas@youhoo.tech: {'name': 'wagnerthomas', 'operator': 'youhoo', 'zone': '.tech'}
# Match found for adamjagtap@hotmoille.apple: {'name': 'adamjagtap', 'operator': 'hotmoille', 'zone': '.apple'}
# Match found for paul.reamer@napster.com: {'name': 'paul', 'last_name': 'reamer', 'operator': 'napster', 'zone': '.com'}
# Match found for adam@belgaximus.io: {'name': 'adam', 'operator': 'belgaximus', 'zone': '.io'}
# Match found for ty@email.tech: {'name': 'ty', 'operator': 'email', 'zone': '.tech'}
# Match found for edward@email.net: {'name': 'edward', 'operator': 'email', 'zone': '.net'}
# Match found for doran2286@imail.org: {'name': 'doran2286', 'operator': 'imail', 'zone': '.org'}
# Match found for irwinhal@belgaximus.tech: {'name': 'irwinhal', 'operator': 'belgaximus', 'zone': '.tech'}
# Match found for tyschwager@odul.tech: {'name': 'tyschwager', 'operator': 'odul', 'zone': '.tech'}
# Match found for georgemills@imail.apple: {'name': 'georgemills', 'operator': 'imail', 'zone': '.apple'}
# Match found for wagle389@odul.com: {'name': 'wagle389', 'operator': 'odul', 'zone': '.com'}
# Match found for edwardferro@hotmoille.net: {'name': 'edwardferro', 'operator': 'hotmoille', 'zone': '.net'}
# Match found for adamostrander@hotmoille.gov: {'name': 'adamostrander', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for keller-ty@youhoo.org: {'name': 'keller', 'last_name': 'ty', 'operator': 'youhoo', 'zone': '.org'}
# Match found for 258546748@imail.org: {'name': '258546748', 'operator': 'imail', 'zone': '.org'}
# Match found for bencaswell@imail.gov: {'name': 'bencaswell', 'operator': 'imail', 'zone': '.gov'}
# Match found for steve1862@hotmoille.com: {'name': 'steve1862', 'operator': 'hotmoille', 'zone': '.com'}
# Match found for halturco@email.hu: {'name': 'halturco', 'operator': 'email', 'zone': '.hu'}
# Match found for tiernan_casal@email.com: {'name': 'tiernan', 'last_name': 'casal', 'operator': 'email', 'zone': '.com'}
# Match found for solberg4139@mail.adlp.tech: {'name': 'solberg4139', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for davidson-otto@youhoo.com: {'name': 'davidson', 'last_name': 'otto', 'operator': 'youhoo', 'zone': '.com'}
# Match found for alexdoran@napster.org: {'name': 'alexdoran', 'operator': 'napster', 'zone': '.org'}
# Match found for thomas@mail.adlp.me: {'name': 'thomas', 'operator': 'mail', 'zone': '.adlp.me'}
# Match found for monte.upson@mail.adlp.com: {'name': 'monte', 'last_name': 'upson', 'operator': 'mail', 'zone': '.adlp.com'}
# Match found for frick_cannon@gaagle.tech: {'name': 'frick', 'last_name': 'cannon', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for otto@email.apple: {'name': 'otto', 'operator': 'email', 'zone': '.apple'}
# Match found for schutz-steve@mail.bocode.xyz: {'name': 'schutz', 'last_name': 'steve', 'operator': 'mail', 'zone': '.bocode.xyz'}
# Match found for ikenorquist@mail.bocode.org: {'name': 'ikenorquist', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for hal@email.tech: {'name': 'hal', 'operator': 'email', 'zone': '.tech'}
# Match found for ulrich.thomas@odul.io: {'name': 'ulrich', 'last_name': 'thomas', 'operator': 'odul', 'zone': '.io'}
# Match found for vader_casal@mail.bocode.org: {'name': 'vader', 'last_name': 'casal', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for aaron@mail.bocode.org: {'name': 'aaron', 'operator': 'mail', 'zone': '.bocode.org'}
# Match found for anderson_aaron@odul.me: {'name': 'anderson', 'last_name': 'aaron', 'operator': 'odul', 'zone': '.me'}
# Match found for aikin8186@mail.bocode.hu: {'name': 'aikin8186', 'operator': 'mail', 'zone': '.bocode.hu'}
# Match found for hoffman_victor@imail.tech: {'name': 'hoffman', 'last_name': 'victor', 'operator': 'imail', 'zone': '.tech'}
# Match found for larrythompson@imail.apple: {'name': 'larrythompson', 'operator': 'imail', 'zone': '.apple'}
# Match found for ebnerjohn@gaagle.apple: {'name': 'ebnerjohn', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for frank.nelson@proton.net: {'name': 'frank', 'last_name': 'nelson', 'operator': 'proton', 'zone': '.net'}
# Match found for ebner_reamer@email.me: {'name': 'ebner', 'last_name': 'reamer', 'operator': 'email', 'zone': '.me'}
# Match found for trusela_paul@imail.me: {'name': 'trusela', 'last_name': 'paul', 'operator': 'imail', 'zone': '.me'}
# Match found for dinkinsalex@email.io: {'name': 'dinkinsalex', 'operator': 'email', 'zone': '.io'}
# Match found for jack3083@belgaximus.gov: {'name': 'jack3083', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for casal@youhoo.gov: {'name': 'casal', 'operator': 'youhoo', 'zone': '.gov'}
# Match found for fred@imail.me: {'name': 'fred', 'operator': 'imail', 'zone': '.me'}
# Match found for davisgeorge@napster.tech: {'name': 'davisgeorge', 'operator': 'napster', 'zone': '.tech'}
# Match found for jagtap@odul.com: {'name': 'jagtap', 'operator': 'odul', 'zone': '.com'}
# Match found for joe1068@mail.adlp.tech: {'name': 'joe1068', 'operator': 'mail', 'zone': '.adlp.tech'}
# Match found for wagner.roger@mail.adlp.apple: {'name': 'wagner', 'last_name': 'roger', 'operator': 'mail', 'zone': '.adlp.apple'}
# Match found for fredvalente@gaagle.me: {'name': 'fredvalente', 'operator': 'gaagle', 'zone': '.me'}
# Match found for hylan.carl@hotmoille.gov: {'name': 'hylan', 'last_name': 'carl', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for 270804951@napster.org: {'name': '270804951', 'operator': 'napster', 'zone': '.org'}
# Match found for uddin1875@napster.apple: {'name': 'uddin1875', 'operator': 'napster', 'zone': '.apple'}
# Match found for turco.carl@belgaximus.tech: {'name': 'turco', 'last_name': 'carl', 'operator': 'belgaximus', 'zone': '.tech'}
# Match found for hoffman@gaagle.apple: {'name': 'hoffman', 'operator': 'gaagle', 'zone': '.apple'}
# Match found for joe.rogers@gaagle.xyz: {'name': 'joe', 'last_name': 'rogers', 'operator': 'gaagle', 'zone': '.xyz'}
# Match found for schmitt_larry@odul.gov: {'name': 'schmitt', 'last_name': 'larry', 'operator': 'odul', 'zone': '.gov'}
# Match found for 879442014@mail.bocode.tech: {'name': '879442014', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for carlsoloman@ecoin.com: {'name': 'carlsoloman', 'operator': 'ecoin', 'zone': '.com'}
# Match found for nathan6115@imail.me: {'name': 'nathan6115', 'operator': 'imail', 'zone': '.me'}
# Match found for frank@imail.io: {'name': 'frank', 'operator': 'imail', 'zone': '.io'}
# Match found for norquist_steve@belgaximus.com: {'name': 'norquist', 'last_name': 'steve', 'operator': 'belgaximus', 'zone': '.com'}
# Match found for delorenzo_peter@mail.adlp.xyz: {'name': 'delorenzo', 'last_name': 'peter', 'operator': 'mail', 'zone': '.adlp.xyz'}
# Match found for paul@hotmoille.gov: {'name': 'paul', 'operator': 'hotmoille', 'zone': '.gov'}
# Match found for orwig@odul.me: {'name': 'orwig', 'operator': 'odul', 'zone': '.me'}
# Match found for dinkins-adam@imail.tech: {'name': 'dinkins', 'last_name': 'adam', 'operator': 'imail', 'zone': '.tech'}
# Match found for tislerdan@hotmoille.tech: {'name': 'tislerdan', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for edward6174@imail.me: {'name': 'edward6174', 'operator': 'imail', 'zone': '.me'}
# Match found for montepettigrew@hotmoille.hu: {'name': 'montepettigrew', 'operator': 'hotmoille', 'zone': '.hu'}
# Match found for schutzlarry@odul.net: {'name': 'schutzlarry', 'operator': 'odul', 'zone': '.net'}
# Match found for zeasertim@proton.tech: {'name': 'zeasertim', 'operator': 'proton', 'zone': '.tech'}
# Match found for walter.kassing@odul.tech: {'name': 'walter', 'last_name': 'kassing', 'operator': 'odul', 'zone': '.tech'}
# Match found for ferro.david@gaagle.tech: {'name': 'ferro', 'last_name': 'david', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for schmitt_schiebel@belgaximus.gov: {'name': 'schmitt', 'last_name': 'schiebel', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for ikethompson@mail.bocode.tech: {'name': 'ikethompson', 'operator': 'mail', 'zone': '.bocode.tech'}
# Match found for martin.ben@imail.me: {'name': 'martin', 'last_name': 'ben', 'operator': 'imail', 'zone': '.me'}
# Match found for benventotla@youhoo.org: {'name': 'benventotla', 'operator': 'youhoo', 'zone': '.org'}
# Match found for ziegler_soloman@imail.io: {'name': 'ziegler', 'last_name': 'soloman', 'operator': 'imail', 'zone': '.io'}
# Match found for davidson_rogers@belgaximus.xyz: {'name': 'davidson', 'last_name': 'rogers', 'operator': 'belgaximus', 'zone': '.xyz'}
# Match found for george@proton.org: {'name': 'george', 'operator': 'proton', 'zone': '.org'}
# Match found for ramachandran431@napster.hu: {'name': 'ramachandran431', 'operator': 'napster', 'zone': '.hu'}
# Match found for paulostrander@youhoo.xyz: {'name': 'paulostrander', 'operator': 'youhoo', 'zone': '.xyz'}
# Match found for tyseverson@hotmoille.hu: {'name': 'tyseverson', 'operator': 'hotmoille', 'zone': '.hu'}
# Match found for edwardortiz@hotmoille.tech: {'name': 'edwardortiz', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for hal5999@email.org: {'name': 'hal5999', 'operator': 'email', 'zone': '.org'}
# Match found for christensen-david@odul.hu: {'name': 'christensen', 'last_name': 'david', 'operator': 'odul', 'zone': '.hu'}
# Match found for mark@mail.adlp.me: {'name': 'mark', 'operator': 'mail', 'zone': '.adlp.me'}
# Match found for bongard-paul@gaagle.xyz: {'name': 'bongard', 'last_name': 'paul', 'operator': 'gaagle', 'zone': '.xyz'}
# Match found for moody3417@ecoin.gov: {'name': 'moody3417', 'operator': 'ecoin', 'zone': '.gov'}
# Match found for trebil_bowers@proton.org: {'name': 'trebil', 'last_name': 'bowers', 'operator': 'proton', 'zone': '.org'}
# Match found for pak9267@ecoin.hu: {'name': 'pak9267', 'operator': 'ecoin', 'zone': '.hu'}
# Match found for 883886499@youhoo.io: {'name': '883886499', 'operator': 'youhoo', 'zone': '.io'}
# Match found for peterknutson@gaagle.hu: {'name': 'peterknutson', 'operator': 'gaagle', 'zone': '.hu'}
# Match found for mark@belgaximus.gov: {'name': 'mark', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for 660694516@napster.apple: {'name': '660694516', 'operator': 'napster', 'zone': '.apple'}
# Match found for larry@belgaximus.gov: {'name': 'larry', 'operator': 'belgaximus', 'zone': '.gov'}
# Match found for wagner-otto@ecoin.apple: {'name': 'wagner', 'last_name': 'otto', 'operator': 'ecoin', 'zone': '.apple'}
# Match found for ripka1096@email.apple: {'name': 'ripka1096', 'operator': 'email', 'zone': '.apple'}
# Match found for bowers.otto@proton.gov: {'name': 'bowers', 'last_name': 'otto', 'operator': 'proton', 'zone': '.gov'}
# Match found for peter2859@mail.adlp.net: {'name': 'peter2859', 'operator': 'mail', 'zone': '.adlp.net'}
# Match found for ulrich_fred@imail.tech: {'name': 'ulrich', 'last_name': 'fred', 'operator': 'imail', 'zone': '.tech'}
# Match found for dugelman_carl@youhoo.io: {'name': 'dugelman', 'last_name': 'carl', 'operator': 'youhoo', 'zone': '.io'}
# Match found for 801140752@email.net: {'name': '801140752', 'operator': 'email', 'zone': '.net'}
# Match found for schutz_otto@mail.adlp.hu: {'name': 'schutz', 'last_name': 'otto', 'operator': 'mail', 'zone': '.adlp.hu'}
# Match found for vader-larry@hotmoille.me: {'name': 'vader', 'last_name': 'larry', 'operator': 'hotmoille', 'zone': '.me'}
# Match found for jurgenson.aaron@napster.io: {'name': 'jurgenson', 'last_name': 'aaron', 'operator': 'napster', 'zone': '.io'}
# Match found for stahl_ty@gaagle.tech: {'name': 'stahl', 'last_name': 'ty', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for lawickimatthew@gaagle.tech: {'name': 'lawickimatthew', 'operator': 'gaagle', 'zone': '.tech'}
# Match found for kassing-victor@gaagle.io: {'name': 'kassing', 'last_name': 'victor', 'operator': 'gaagle', 'zone': '.io'}
# Match found for halbongard@hotmoille.tech: {'name': 'halbongard', 'operator': 'hotmoille', 'zone': '.tech'}
# Match found for soukup.roger@youhoo.com: {'name': 'soukup', 'last_name': 'roger', 'operator': 'youhoo', 'zone': '.com'}
# Match found for 733095700@mail.adlp.io: {'name': '733095700', 'operator': 'mail', 'zone': '.adlp.io'}
# Match found for jack.sweeney@hotmoille.org: {'name': 'jack', 'last_name': 'sweeney', 'operator': 'hotmoille', 'zone': '.org'}

# %% [markdown]
# **12. Another way of doing things.**

# %%
mail = "audrey.boulevart@benextcomapgny.com"
splitMail = mail.replace(".", " ").split("@").copy()

firstName = []
name = []
ope = []
zone = []

print(splitMail)
firstName.append(splitMail[0].split()[0])
name.append(splitMail[0].split()[-1])
ope.append(splitMail[1].split()[0])
zone.append(splitMail[1].split()[-1])

firstName, name, ope, zone
# Out:
# ['audrey boulevart', 'benextcomapgny com']
# (['audrey'], ['boulevart'], ['benextcomapgny'], ['com'])

# %%
with open("./data/mail.txt") as file:
    list_mail = file.readlines() 

for email in list_mail:
    split_mail = email.replace("-"," ").replace("."," ").replace("_", " ").strip().split("@")

firstName = []
name = []
ope = []
zone = []

firstName.append(split_mail[0].split()[0])
name.append(split_mail[0].split()[-1])
ope.append(split_mail[1].split()[0])
zone.append(split_mail[1].split()[-1])

print(firstName[0])
# Out:
# jack

# %% [markdown]
# Repeat the previous exercise with this new formula and compare the length of your lists with those of the previous exercise.
# What do you notice ?
